# %%
import json
import os
import pandas
import pyarrow
import sys

from dotenv import load_dotenv
from sqlalchemy import create_engine
from os import path

load_dotenv(verbose=True)
BIGQUERY_CREDENTIALS_PATH = os.environ.get('BIGQUERY_CREDENTIALS_PATH')
engine = create_engine('bigquery://bespoke-financial/ProdMetrcData', credentials_path=os.path.expanduser(BIGQUERY_CREDENTIALS_PATH))

sys.path.append(path.realpath(path.join(os.getcwd(), "../core")))

import create_queries
import prepare_data

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Example of parent and child packages
# 1. Start from a child package
# 2. Find parent package
# 3. Find other child package(s)

# %%
packages_by_package_id_query = create_queries.create_packages_by_package_id_query('2673316')
packages_by_package_id_dataframe = pandas.read_sql_query(packages_by_package_id_query, engine)
packages_by_package_id_dataframe
# Out:
#   identifier license_number    type package_type product_category_name  \
# 0        BBF       MR281525  active      Product         Raw Pre-Rolls
#
#                                   product_name package_id  \
# 0  M00000889617: BBF - Sira SFV OG Pre Roll 1g    2673316
#
#               package_label  quantity unit_of_measure  ...  \
# 0  1A40A0300001B59000000215      91.0           Grams  ...
#
#            last_modified_at packaged_date                       updated_at  \
# 0 2021-10-29 15:05:20+00:00    2021-09-23 2021-10-29 15:36:56.037000+00:00
#
#                         created_at quantity_1 unit_of_measure_1  \
# 0 2021-10-29 00:16:24.517000+00:00       91.0             Grams
#
#   license_number_1 us_state __hevo__ingested_at __hevo__loaded_at
# 0         MR281525       MA       1635526970462     1635527444188
#
# [1 rows x 29 columns]

# %%
child_package = packages_by_package_id_dataframe.to_dict('records')[0]
child_package
# Out:
# {'identifier': 'BBF',
#  'license_number': 'MR281525',
#  'type': 'active',
#  'package_type': 'Product',
#  'product_category_name': 'Raw Pre-Rolls',
#  'product_name': 'M00000889617: BBF - Sira SFV OG Pre Roll 1g',
#  'package_id': '2673316',
#  'package_label': '1A40A0300001B59000000215',
#  'quantity': 91.0,
#  'unit_of_measure': 'Grams',
#  'id': 'af30df97-9497-4723-a8fe-759a423bed31',
#  'type_1': 'active',
#  'company_id': '08ef04eb-a9b0-45a3-aee6-8d0b131a8eab',
#  'package_id_1': '2673316',
#  'package_label_1': '1A40A0300001B59000000215',
#  'package_type_1': 'Product',
#  'product_name_1': 'M00000889617: BBF - Sira SFV OG Pre Roll 1g',
#  'product_category_name_1': 'Raw Pre-Rolls',
#  'package_payload': {'id': 2673316,
#   'label': '1A40A0300001B59000000215',
#   'packagetype': 'Product',
#   'sourceharvestnames': 'SFVM22107214',
#   'quantity': 91.0,
#   'unitofmeasurename': 'Grams',
#   'unitofmeasureabbreviation': 'g',
#   'patientlicensenumber': '',
#   'itemfromfacilitylicensenumber': 'MR281525',
#   'itemfromfacilityname': 'Boston Bud Factory Inc.',
#   'note': 'converted 171g of flower into 169 1g pre rolls. 2g processing loss.',
#   'packageddate': '2021-09-23',
#   'initiallabtestingstate': 'TestPassed',
#   'labtestingstate': 'TestPassed',
#   'labtestingstatedate': '2021-09-23',
#   'isproductionbatch': False,
#   'productionbatchnumber': '',
#   'sourceproductionbatchnumbers': 'SFVM22107214-3',
#   'istradesample': False,
#   'istradesamplepersistent': False,
#   'sourcepackageistradesample': False,
#   'isdonation': False,
#   'isdonationpersistent': False,
#   'sourcepackageisdonation': False,
#   'istestingsample': False,
#   'isprocessvalidationtestingsample': False,
#   'productrequiresremediation': False,
#   'containsremediatedproduct': False,
#   'isonhold': False,
#   'lastmodified': '2021-10-29T11:05:20-04:00',
#   'itemid': 889617,
#   'itemname': 'M00000889617: BBF - Sira SFV OG Pre Roll 1g',
#   'itemproductcategoryname': 'Raw Pre-Rolls',
#   'itemproductcategorytype': 'ShakeTrim',
#   'itemquantitytype': 'WeightBased',
#   'itemdefaultlabtestingstate': 'NotSubmitted',
#   'itemunitofmeasurename': 'Grams',
#   'itemapprovalstatus': 'Approved',
#   'itemapprovalstatusdatetime': '2021-03-26T18:04:30+00:00',
#   'itemstrainid': None,
#   'itemstrainname': None,
#   'itemadministrationmethod': '',
#   'itemservingsize': '',
#   'itempublicingredients': '',
#   'itemdescription': '',
#   'itemisused': False,
#   'itemunitweight': None,
#   'itemunitweightunitofmeasurename': None,
#   'receiveddatetime': None,
#   'receivedfrommanifestnumber': None,
#   'receivedfromfacilitylicensenumber': None,
#   'receivedfromfacilityname': None,
#   'finisheddate': None,
#   'locationid': 71502,
#   'locationname': 'Boston Bud Factory-Retail',
#   'locationtypename': 'Default Location Type',
#   'itemunitvolume': None,
#   'itemunitvolumeunitofmeasurename': None,
#   'archiveddate': None,
#   'itemunitthccontent': None,
#   'itemunitthccontentunitofmeasurename': None,
#   'remediationdate': None,
#   'itemunitcbdcontent': None,
#   'itemunitcbdcontentunitofmeasurename': None},
#  'last_modified_at': Timestamp('2021-10-29 15:05:20+0000', tz='UTC'),
#  'packaged_date': datetime.date(2021, 9, 23),
#  'updated_at': Timestamp('2021-10-29 15:36:56.037000+0000', tz='UTC'),
#  'created_at': Timestamp('2021-10-29 00:16:24.517000+0000', tz='UTC'),
#  'quantity_1': 91.0,
#  'unit_of_measure_1': 'Grams',
#  'license_number_1': 'MR281525',
#  'us_state': 'MA',
#  '__hevo__ingested_at': 1635526970462,
#  '__hevo__loaded_at': 1635527444188}

# %%
source_production_batch_number = child_package['package_payload']['sourceproductionbatchnumbers']
source_production_batch_number
# Out:
# 'SFVM22107214-3'

# %%
packages_by_production_batch_number_query = create_queries.create_packages_by_production_batch_number_query(source_production_batch_number)
packages_by_production_batch_number_dataframe = pandas.read_sql_query(packages_by_production_batch_number_query, engine)
packages_by_production_batch_number_dataframe
# Out:
#   identifier license_number    type package_type product_category_name  \
# 0        BBF       MR281525  active      Product                  Buds
#
#                            product_name package_id             package_label  \
# 0  M00000198133: Sira SFV OG A Bud Bulk    2550280  1A40A030000025A000034007
#
#    quantity unit_of_measure  ...          last_modified_at packaged_date  \
# 0     139.3           Grams  ... 2021-10-29 13:34:07+00:00    2021-09-01
#
#                         updated_at                       created_at  \
# 0 2021-10-29 15:36:56.578000+00:00 2021-10-29 00:16:28.101000+00:00
#
#   quantity_1 unit_of_measure_1 license_number_1 us_state __hevo__ingested_at  \
# 0      139.3             Grams         MR281525       MA       1635526970502
#
#   __hevo__loaded_at
# 0     1635527444188
#
# [1 rows x 29 columns]

# %%
parent_package = packages_by_production_batch_number_dataframe.to_dict('records')[0]
parent_package
# Out:
# {'identifier': 'BBF',
#  'license_number': 'MR281525',
#  'type': 'active',
#  'package_type': 'Product',
#  'product_category_name': 'Buds',
#  'product_name': 'M00000198133: Sira SFV OG A Bud Bulk',
#  'package_id': '2550280',
#  'package_label': '1A40A030000025A000034007',
#  'quantity': 139.3,
#  'unit_of_measure': 'Grams',
#  'id': 'f08f2222-b28d-44df-915b-25ba88acfa39',
#  'type_1': 'active',
#  'company_id': '08ef04eb-a9b0-45a3-aee6-8d0b131a8eab',
#  'package_id_1': '2550280',
#  'package_label_1': '1A40A030000025A000034007',
#  'package_type_1': 'Product',
#  'product_name_1': 'M00000198133: Sira SFV OG A Bud Bulk',
#  'product_category_name_1': 'Buds',
#  'package_payload': {'id': 2550280,
#   'label': '1A40A030000025A000034007',
#   'packagetype': 'Product',
#   'sourceharvestnames': 'SFVM22107214',
#   'quantity': 139.3,
#   'unitofmeasurename': 'Grams',
#   'unitofmeasureabbreviation': 'g',
#   'patientlicensenumber': '',
#   'itemfromfacilitylicensenumber': 'MC282015',
#   'itemfromfacilityname': 'SIRA NATURALS, INC.',
#   'note': '',
#   'packageddate': '2021-09-01',
#   'initiallabtestingstate': 'TestPassed',
#   'labtestingstate': 'TestPassed',
#   'labtestingstatedate': '2021-09-01',
#   'isproductionbatch': False,
#   'productionbatchnumber': 'SFVM22107214-3',
#   'sourceproductionbatchnumbers': 'SFVM22107214-3',
#   'istradesample': False,
#   'istradesamplepersistent': False,
#   'sourcepackageistradesample': False,
#   'isdonation': False,
#   'isdonationpersistent': False,
#   'sourcepackageisdonation': False,
#   'istestingsample': False,
#   'isprocessvalidationtestingsample': False,
#   'productrequiresremediation': False,
#   'containsremediatedproduct': False,
#   'isonhold': False,
#   'lastmodified': '2021-10-29T09:34:07-04:00',
#   'itemid': 198133,
#   'itemname': 'M00000198133: Sira SFV OG A Bud Bulk',
#   'itemproductcategoryname': 'Buds',
#   'itemproductcategorytype': 'Buds',
#   'itemquantitytype': 'WeightBased',
#   'itemdefaultlabtestingstate': 'NotSubmitted',
#   'itemunitofmeasurename': 'Grams',
#   'itemapprovalstatus': 'Approved',
#   'itemapprovalstatusdatetime': '0001-01-01T00:00:00+00:00',
#   'itemstrainid': 71444,
#   'itemstrainname': 'SFV OG',
#   'itemadministrationmethod': '',
#   'itemservingsize': '',
#   'itempublicingredients': '',
#   'itemdescription': '',
#   'itemisused': False,
#   'itemunitweight': None,
#   'itemunitweightunitofmeasurename': None,
#   'receiveddatetime': '2021-09-07T14:24:49+00:00',
#   'receivedfrommanifestnumber': '0000719005',
#   'receivedfromfacilitylicensenumber': 'MP281303',
#   'receivedfromfacilityname': 'SIRA NATURALS, INC.',
#   'finisheddate': None,
#   'locationid': 76101,
#   'locationname': 'Boston Bud Factory - Vault',
#   'locationtypename': 'Default Location Type',
#   'itemunitvolume': None,
#   'itemunitvolumeunitofmeasurename': None,
#   'archiveddate': None,
#   'itemunitthccontent': None,
#   'itemunitthccontentunitofmeasurename': None,
#   'remediationdate': None,
#   'itemunitcbdcontent': None,
#   'itemunitcbdcontentunitofmeasurename': None},
#  'last_modified_at': Timestamp('2021-10-29 13:34:07+0000', tz='UTC'),
#  'packaged_date': datetime.date(2021, 9, 1),
#  'updated_at': Timestamp('2021-10-29 15:36:56.578000+0000', tz='UTC'),
#  'created_at': Timestamp('2021-10-29 00:16:28.101000+0000', tz='UTC'),
#  'quantity_1': 139.3,
#  'unit_of_measure_1': 'Grams',
#  'license_number_1': 'MR281525',
#  'us_state': 'MA',
#  '__hevo__ingested_at': 1635526970502,
#  '__hevo__loaded_at': 1635527444188}

# %%
parent_package_id = parent_package['package_id']
parent_package_id
# Out:
# '2550280'

# %%
transfer_packages_by_package_id_query = create_queries.create_transfer_packages_by_package_id_query(parent_package_id)
transfer_packages_by_package_id_dataframe = pandas.read_sql_query(transfer_packages_by_package_id_query, engine)
transfer_packages_by_package_id_dataframe
# Out:
#   identifier     delivery_type                       updated_at  \
# 0        BBF  INCOMING_UNKNOWN 2021-10-28 23:46:59.430000+00:00
#
#           received_datetime package_id             package_label packagetype  \
# 0 2021-09-07 14:24:49+00:00    2550280  1A40A030000025A000034007     Product
#
#    shipped_quantity  shipper_wholesale_price  received_quantity  \
# 0            1002.0                  8386.78             1002.0
#
#   shipper_facility_name shipper_facility_license_number  \
# 0   SIRA NATURALS, INC.                        MP281303
#
#    recipient_facility_name recipient_facility_license_number
# 0  Boston Bud Factory Inc.                          MR281525

# %%
packages_by_source_production_batch_number_query = create_queries.create_packages_by_source_production_batch_number_query(source_production_batch_number)
packages_by_source_production_batch_number_dataframe = pandas.read_sql_query(packages_by_source_production_batch_number_query, engine)
packages_by_source_production_batch_number_dataframe
# Out:
#   identifier license_number    type package_type product_category_name  \
# 0        BBF       MR281525  active      Product                  Buds
# 1        BBF       MR281525  active      Product                  Buds
# 2        BBF       MR281525  active      Product         Raw Pre-Rolls
# 3        BBF       MR281525  active      Product         Raw Pre-Rolls
# 4        BBF       MR281525  active      Product         Raw Pre-Rolls
#
#                                    product_name package_id  \
# 0          M00000784201: BBF - Sira SFV OG 3.5g    2670998
# 1          M00000198133: Sira SFV OG A Bud Bulk    2550280
# 2   M00000889617: BBF - Sira SFV OG Pre Roll 1g    2673316
# 3   M00000889617: BBF - Sira SFV OG Pre Roll 1g    2842719
# 4  M00001233701: BBF - Sira SFV OG Pre Roll .5g    2673807
#
#               package_label  quantity unit_of_measure  ...  \
# 0  1A40A0300001B59000000214     434.0           Grams  ...
# 1  1A40A030000025A000034007     139.3           Grams  ...
# 2  1A40A0300001B59000000215      91.0           Grams  ...
# 3  1A40A0300001B59000000231     169.0           Grams  ...
# 4  1A40A0300001B59000000216      72.5           Grams  ...
#
#            last_modified_at packaged_date                       updated_at  \
# 0 2021-10-29 13:21:44+00:00    2021-09-23 2021-10-29 15:36:56.037000+00:00
# 1 2021-10-29 13:34:07+00:00    2021-09-01 2021-10-29 15:36:56.578000+00:00
# 2 2021-10-29 15:05:20+00:00    2021-09-23 2021-10-29 15:36:56.037000+00:00
# 3 2021-10-29 13:34:50+00:00    2021-10-23 2021-10-29 15:36:56.037000+00:00
# 4 2021-10-29 13:21:44+00:00    2021-09-23 2021-10-29 15:36:56.037000+00:00
#
#                         created_at quantity_1 unit_of_measure_1  \
# 0 2021-10-29 00:16:24.431000+00:00      434.0             Grams
# 1 2021-10-29 00:16:28.101000+00:00      139.3             Grams
# 2 2021-10-29 00:16:24.517000+00:00       91.0             Grams
# 3 2021-10-29 00:16:21.074000+00:00      169.0             Grams
# 4 2021-10-29 00:16:24.597000+00:00       72.5             Grams
#
#   license_number_1 us_state __hevo__ingested_at __hevo__loaded_at
# 0         MR281525       MA       1635526970452     1635527444188
# 1         MR281525       MA       1635526970502     1635527444188
# 2         MR281525       MA       1635526970462     1635527444188
# 3         MR281525       MA       1635526970444     1635527444188
# 4         MR281525       MA       1635526970468     1635527444188
#
# [5 rows x 29 columns]
