# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import json
import numpy 
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import pyarrow
import sys

from datetime import date
from dotenv import load_dotenv
from sqlalchemy import create_engine
from os import path
from typing import List,Dict, Tuple
from collections import defaultdict
pd.set_option("display.max_columns", None)

load_dotenv(verbose=True)
BIGQUERY_CREDENTIALS_PATH = os.environ.get('BIGQUERY_CREDENTIALS_PATH')
engine = create_engine('bigquery://bespoke-financial/ProdMetrcData', credentials_path=os.path.expanduser(BIGQUERY_CREDENTIALS_PATH))

sys.path.append(path.realpath(path.join(os.getcwd(), "../core")))
sys.path.append(path.realpath(path.join(os.getcwd(), "../../src")))

import create_queries
import prepare_data

from bespoke.inventory.analysis.shared import download_util, inventory_types
from bespoke.inventory.analysis import active_inventory_util as util
from bespoke.inventory.analysis import inventory_valuations_util as valuations_util

# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv('finance_margin_analysis.csv')

# %%
data
# Out:
#          date    revenue           cogs      margin_$  margin_%  \
# 0     2021-01  291646.25   69944.725610  221701.52440  0.760173
# 1     2021-02  262906.73   85322.341900  177584.38810  0.675465
# 2     2021-03  315154.72   99950.244010  215204.47600  0.682853
# 3     2021-04  329925.48  100937.302800  228988.17720  0.694060
# 4     2021-05  336793.80   99047.578800  237746.22120  0.705910
# ...       ...        ...            ...           ...       ...
# 2345  2021-11   18761.21    5470.325953   13290.88405  0.708424
# 2346  2021-12   32715.38   12198.903890   20516.47611  0.627120
# 2347  2022-01   24339.01   11123.403850   13215.60615  0.542980
# 2348  2022-02   24450.82   10410.082940   14040.73706  0.574244
# 2349  2022-03   13202.18    5924.797400    7277.38260  0.551226
#
#       total_count_incoming  product_count  count_incoming  coverage  \
# 0                     4808           2003            2805  0.696005
# 1                     5464            377            5087  0.948611
# 2                     6902            159            6743  0.951475
# 3                     7081            112            6969  0.931465
# 4                     7286            131            7155  0.918326
# ...                    ...            ...             ...       ...
# 2345                   610             52             558  0.884058
# 2346                  1062            129             933  0.919481
# 2347                   831             43             788  0.936866
# 2348                   796             37             759  0.953293
# 2349                   433             21             412  0.973034
#
#       revenue_after_tax  cogs_after_tax  margin_$_after_tax  \
# 0           335393.1875    88829.801520       246563.386000
# 1           302342.7395   108359.374200       193983.365300
# 2           362427.9280   126936.809900       235491.118100
# 3           379414.3020   128190.374500       251223.927500
# 4           387312.8700   125790.425100       261522.444900
# ...                 ...             ...                 ...
# 2345         21575.3915     6947.313960        14628.077540
# 2346         37622.6870    15492.607940        22130.079060
# 2347         27989.8615    14126.722890        13863.138610
# 2348         28118.4430    13220.805330        14897.637670
# 2349         15182.5070     7524.492698         7658.014302
#
#       margin_%_after_tax  gm_past_quarter_after_tax  \
# 0               0.735147                        NaN
# 1               0.641601                        NaN
# 2               0.649760                   0.675503
# 3               0.662136                   0.651166
# 4               0.675223                   0.662373
# ...                  ...                        ...
# 2345            0.677998                   0.591387
# 2346            0.588211                   0.644411
# 2347            0.495291                   0.587167
# 2348            0.529817                   0.537773
# 2349            0.504397                   0.509835
#
#       gm_past_2quarters_after_tax  gm_past_3quarters_after_tax  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 2345                          NaN                          NaN
# 2346                          NaN                          NaN
# 2347                          NaN                          NaN
# 2348                     0.564580                          NaN
# 2349                     0.577123                          NaN
#
#       gm$_past_quarter_after_tax  gm$_past_2quarters_after_tax  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                   225345.95650                           NaN
# 3                   226899.47030                           NaN
# 4                   249412.49680                           NaN
# ...                          ...                           ...
# 2345                 12210.38262                           NaN
# 2346                 16567.28353                           NaN
# 2347                 16873.76507                           NaN
# 2348                 16963.61845                   14587.00053
# 2349                 12139.59686                   14353.44019
#
#       gm$_past_3quarters_after_tax company         location  \
# 0                              NaN    99HT  C10-0000279-LIC
# 1                              NaN    99HT  C10-0000279-LIC
# 2                              NaN    99HT  C10-0000279-LIC
# 3                              NaN    99HT  C10-0000279-LIC
# 4                              NaN    99HT  C10-0000279-LIC
# ...                            ...     ...              ...
# 2345                           NaN     VOY  C10-0000802-LIC
# 2346                           NaN     VOY  C10-0000802-LIC
# 2347                           NaN     VOY  C10-0000802-LIC
# 2348                           NaN     VOY  C10-0000802-LIC
# 2349                           NaN     VOY  C10-0000802-LIC
#
#                                id company_identifier state
# 0     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 1     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 2     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 3     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 4     ('99HT', 'C10-0000279-LIC')               99HT    CA
# ...                           ...                ...   ...
# 2345   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2346   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2347   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2348   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2349   ('VOY', 'C10-0000802-LIC')                VOY    CA
#
# [2350 rows x 24 columns]

# %%
df_clients = [
'DL',
'DW',
'EMA',
'EMM',
'EMT',
'EMF',
'ST',
'GRG',
'EL',
'VS',
'TT',
'MD',
'DWF',
'GHC',
'SV',
'99HT'
]

# %%
data_client = data[data['company_identifier'].isin(df_clients)]

# %%
data_client['company_identifier'].unique()
# Out:
# array(['99HT', 'DWF', 'DL', 'EL', 'EMA', 'EMF', 'EMM', 'EMT', 'GRG',
#        'GHC', 'MD', 'SV', 'ST', 'DW', 'TT', 'VS'], dtype=object)

# %%
data_client
# Out:
#          date    revenue          cogs      margin_$  margin_%  \
# 0     2021-01  291646.25   69944.72561  221701.52440  0.760173
# 1     2021-02  262906.73   85322.34190  177584.38810  0.675465
# 2     2021-03  315154.72   99950.24401  215204.47600  0.682853
# 3     2021-04  329925.48  100937.30280  228988.17720  0.694060
# 4     2021-05  336793.80   99047.57880  237746.22120  0.705910
# ...       ...        ...           ...           ...       ...
# 2338  2021-11  517332.55  240108.39600  277224.15400  0.535872
# 2339  2021-12  440912.77  212389.01800  228523.75200  0.518297
# 2340  2022-01  435566.37  177725.05480  257841.31520  0.591968
# 2341  2022-02  393248.45  215992.40210  177256.04790  0.450748
# 2342  2022-03  207896.11  121650.61590   86245.49414  0.414849
#
#       total_count_incoming  product_count  count_incoming  coverage  \
# 0                     4808           2003            2805  0.696005
# 1                     5464            377            5087  0.948611
# 2                     6902            159            6743  0.951475
# 3                     7081            112            6969  0.931465
# 4                     7286            131            7155  0.918326
# ...                    ...            ...             ...       ...
# 2338                 15731            380           15351  0.935033
# 2339                 13516              0           13516  0.936855
# 2340                 12801              0           12801  0.922462
# 2341                 12013            132           11881  0.934864
# 2342                  6497             91            6406  0.953338
#
#       revenue_after_tax  cogs_after_tax  margin_$_after_tax  \
# 0           335393.1875     88829.80152        246563.38600
# 1           302342.7395    108359.37420        193983.36530
# 2           362427.9280    126936.80990        235491.11810
# 3           379414.3020    128190.37450        251223.92750
# 4           387312.8700    125790.42510        261522.44490
# ...                 ...             ...                 ...
# 2338        594932.4325    304937.66290        289994.76960
# 2339        507049.6855    269734.05290        237315.63260
# 2340        500901.3255    225710.81950        275190.50600
# 2341        452235.7175    274310.35060        177925.36690
# 2342        239080.5265    154496.28210         84584.24436
#
#       margin_%_after_tax  gm_past_quarter_after_tax  \
# 0               0.735147                        NaN
# 1               0.641601                        NaN
# 2               0.649760                   0.675503
# 3               0.662136                   0.651166
# 4               0.675223                   0.662373
# ...                  ...                        ...
# 2338            0.487442                   0.451398
# 2339            0.468032                   0.481002
# 2340            0.549391                   0.501621
# 2341            0.393435                   0.470286
# 2342            0.353790                   0.432205
#
#       gm_past_2quarters_after_tax  gm_past_3quarters_after_tax  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 2338                     0.421637                     0.397003
# 2339                     0.443337                     0.414475
# 2340                     0.469824                     0.432725
# 2341                     0.460842                     0.437853
# 2342                     0.456604                     0.439627
#
#       gm$_past_quarter_after_tax  gm$_past_2quarters_after_tax  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                    225345.9565                           NaN
# 3                    226899.4703                           NaN
# 4                    249412.4968                           NaN
# ...                          ...                           ...
# 2338                 279151.7113                   263050.0522
# 2339                 277087.5208                   268507.2156
# 2340                 267500.3027                   273004.1922
# 2341                 230143.8352                   254647.7733
# 2342                 179233.3724                   228160.4466
#
#       gm$_past_3quarters_after_tax company         location  \
# 0                              NaN    99HT  C10-0000279-LIC
# 1                              NaN    99HT  C10-0000279-LIC
# 2                              NaN    99HT  C10-0000279-LIC
# 3                              NaN    99HT  C10-0000279-LIC
# 4                              NaN    99HT  C10-0000279-LIC
# ...                            ...     ...              ...
# 2338                   248627.1309      VS       402R-00545
# 2339                   253221.0241      VS       402R-00545
# 2340                   256284.9332      VS       402R-00545
# 2341                   252081.3132      VS       402R-00545
# 2342                   238749.2679      VS       402R-00545
#
#                                id company_identifier state
# 0     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 1     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 2     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 3     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 4     ('99HT', 'C10-0000279-LIC')               99HT    CA
# ...                           ...                ...   ...
# 2338         ('VS', '402R-00545')                 VS    CO
# 2339         ('VS', '402R-00545')                 VS    CO
# 2340         ('VS', '402R-00545')                 VS    CO
# 2341         ('VS', '402R-00545')                 VS    CO
# 2342         ('VS', '402R-00545')                 VS    CO
#
# [319 rows x 24 columns]

# %%
margin_distr = data_client.groupby(['date'])['margin_%_after_tax'].describe().reset_index()
margin_distr['date'] = pd.to_datetime(margin_distr['date'])

# %%
margin_distr[margin_distr['date'] >= '2021-01-01']
# Out:
#          date  count      mean       std       min       25%       50%  \
# 12 2021-01-01   13.0  0.555652  0.141233  0.308966  0.469960  0.586887
# 13 2021-02-01   13.0  0.534143  0.106342  0.329721  0.462279  0.558735
# 14 2021-03-01   14.0  0.509222  0.107140  0.310783  0.455558  0.513871
# 15 2021-04-01   14.0  0.514971  0.106578  0.273334  0.469101  0.532922
# 16 2021-05-01   14.0  0.527344  0.093206  0.347279  0.472298  0.536462
# 17 2021-06-01   14.0  0.516664  0.091134  0.337830  0.482937  0.523131
# 18 2021-07-01   15.0  0.510289  0.089101  0.303609  0.463669  0.523964
# 19 2021-08-01   16.0  0.492922  0.102951  0.211764  0.456647  0.492706
# 20 2021-09-01   17.0  0.494927  0.115393  0.243394  0.465847  0.512738
# 21 2021-10-01   17.0  0.510976  0.080358  0.306260  0.476219  0.545595
# 22 2021-11-01   17.0  0.518931  0.081665  0.297024  0.478397  0.538763
# 23 2021-12-01   17.0  0.520955  0.088432  0.285628  0.485569  0.556784
# 24 2022-01-01   17.0  0.524503  0.099092  0.283827  0.482744  0.559739
# 25 2022-02-01   18.0  0.526268  0.088426  0.338828  0.487990  0.527762
# 26 2022-03-01   18.0  0.505993  0.133547  0.135663  0.455158  0.569583
#
#          75%       max
# 12  0.624697  0.790569
# 13  0.629182  0.661451
# 14  0.590789  0.649760
# 15  0.590413  0.662136
# 16  0.598896  0.675223
# 17  0.574560  0.666557
# 18  0.566030  0.650712
# 19  0.555278  0.649505
# 20  0.547641  0.713748
# 21  0.555464  0.607659
# 22  0.580818  0.617833
# 23  0.576563  0.632256
# 24  0.578757  0.632573
# 25  0.590517  0.662175
# 26  0.586831  0.657604

# %%
data_high_coverage = data[data['coverage'] >= 0.8]

# %%
data_high_coverage
# Out:
#          date    revenue           cogs      margin_$  margin_%  \
# 1     2021-02  262906.73   85322.341900  177584.38810  0.675465
# 2     2021-03  315154.72   99950.244010  215204.47600  0.682853
# 3     2021-04  329925.48  100937.302800  228988.17720  0.694060
# 4     2021-05  336793.80   99047.578800  237746.22120  0.705910
# 5     2021-06  324788.69   98065.517010  226723.17300  0.698064
# ...       ...        ...            ...           ...       ...
# 2345  2021-11   18761.21    5470.325953   13290.88405  0.708424
# 2346  2021-12   32715.38   12198.903890   20516.47611  0.627120
# 2347  2022-01   24339.01   11123.403850   13215.60615  0.542980
# 2348  2022-02   24450.82   10410.082940   14040.73706  0.574244
# 2349  2022-03   13202.18    5924.797400    7277.38260  0.551226
#
#       total_count_incoming  product_count  count_incoming  coverage  \
# 1                     5464            377            5087  0.948611
# 2                     6902            159            6743  0.951475
# 3                     7081            112            6969  0.931465
# 4                     7286            131            7155  0.918326
# 5                     6860            114            6746  0.926026
# ...                    ...            ...             ...       ...
# 2345                   610             52             558  0.884058
# 2346                  1062            129             933  0.919481
# 2347                   831             43             788  0.936866
# 2348                   796             37             759  0.953293
# 2349                   433             21             412  0.973034
#
#       revenue_after_tax  cogs_after_tax  margin_$_after_tax  \
# 1           302342.7395   108359.374200       193983.365300
# 2           362427.9280   126936.809900       235491.118100
# 3           379414.3020   128190.374500       251223.927500
# 4           387312.8700   125790.425100       261522.444900
# 5           373506.9935   124543.206600       248963.786900
# ...                 ...             ...                 ...
# 2345         21575.3915     6947.313960        14628.077540
# 2346         37622.6870    15492.607940        22130.079060
# 2347         27989.8615    14126.722890        13863.138610
# 2348         28118.4430    13220.805330        14897.637670
# 2349         15182.5070     7524.492698         7658.014302
#
#       margin_%_after_tax  gm_past_quarter_after_tax  \
# 1               0.641601                        NaN
# 2               0.649760                   0.675503
# 3               0.662136                   0.651166
# 4               0.675223                   0.662373
# 5               0.666557                   0.667972
# ...                  ...                        ...
# 2345            0.677998                   0.591387
# 2346            0.588211                   0.644411
# 2347            0.495291                   0.587167
# 2348            0.529817                   0.537773
# 2349            0.504397                   0.509835
#
#       gm_past_2quarters_after_tax  gm_past_3quarters_after_tax  \
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# 5                        0.671737                          NaN
# ...                           ...                          ...
# 2345                          NaN                          NaN
# 2346                          NaN                          NaN
# 2347                          NaN                          NaN
# 2348                     0.564580                          NaN
# 2349                     0.577123                          NaN
#
#       gm$_past_quarter_after_tax  gm$_past_2quarters_after_tax  \
# 1                            NaN                           NaN
# 2                   225345.95650                           NaN
# 3                   226899.47030                           NaN
# 4                   249412.49680                           NaN
# 5                   253903.38640                  239624.67140
# ...                          ...                           ...
# 2345                 12210.38262                           NaN
# 2346                 16567.28353                           NaN
# 2347                 16873.76507                           NaN
# 2348                 16963.61845                   14587.00053
# 2349                 12139.59686                   14353.44019
#
#       gm$_past_3quarters_after_tax company         location  \
# 1                              NaN    99HT  C10-0000279-LIC
# 2                              NaN    99HT  C10-0000279-LIC
# 3                              NaN    99HT  C10-0000279-LIC
# 4                              NaN    99HT  C10-0000279-LIC
# 5                              NaN    99HT  C10-0000279-LIC
# ...                            ...     ...              ...
# 2345                           NaN     VOY  C10-0000802-LIC
# 2346                           NaN     VOY  C10-0000802-LIC
# 2347                           NaN     VOY  C10-0000802-LIC
# 2348                           NaN     VOY  C10-0000802-LIC
# 2349                           NaN     VOY  C10-0000802-LIC
#
#                                id company_identifier state
# 1     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 2     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 3     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 4     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 5     ('99HT', 'C10-0000279-LIC')               99HT    CA
# ...                           ...                ...   ...
# 2345   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2346   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2347   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2348   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2349   ('VOY', 'C10-0000802-LIC')                VOY    CA
#
# [1378 rows x 24 columns]

# %%
margin_distr_high = data_high_coverage.groupby(['date'])['margin_%'].describe().reset_index()
margin_distr_high['date'] = pd.to_datetime(margin_distr_high['date'])

# %%
margin_distr_high[margin_distr_high['date'] >= '2021-01-01']
# Out:
#          date  count       mean         std          min       25%       50%  \
# 12 2021-01-01   43.0   0.380038    0.979454    -5.823773  0.454279  0.538247
# 13 2021-02-01   53.0   0.169221    1.589999    -9.132750  0.449937  0.524454
# 14 2021-03-01   57.0   0.297040    0.900478    -5.139432  0.426126  0.511427
# 15 2021-04-01   64.0  -0.171296    2.320035   -10.460928  0.394705  0.511804
# 16 2021-05-01   66.0  -0.358163    3.643938   -23.562108  0.428563  0.534181
# 17 2021-06-01   67.0  -0.219760    4.242715   -33.408254  0.420821  0.532507
# 18 2021-07-01   69.0   0.039624    3.427150   -27.663804  0.448063  0.533427
# 19 2021-08-01   73.0 -34.297957  294.389706 -2515.012432  0.435221  0.524525
# 20 2021-09-01   75.0   0.072047    3.374918   -28.564076  0.434799  0.517214
# 21 2021-10-01   81.0   0.058284    3.880241   -34.353985  0.421040  0.521561
# 22 2021-11-01   80.0   0.432374    0.505597    -3.091514  0.418316  0.528176
# 23 2021-12-01   77.0   0.340192    1.595007   -13.435264  0.452822  0.520987
# 24 2022-01-01   74.0   0.322089    1.478807   -11.937174  0.433839  0.535519
# 25 2022-02-01   72.0   0.304807    1.152096    -7.263683  0.447690  0.534277
# 26 2022-03-01   62.0   0.374741    1.070666    -7.802242  0.457156  0.524233
#
#          75%       max
# 12  0.630613  0.749541
# 13  0.600203  0.714314
# 14  0.598422  0.721043
# 15  0.586286  0.722108
# 16  0.605583  0.705910
# 17  0.606989  0.700282
# 18  0.607178  0.733125
# 19  0.594221  0.741826
# 20  0.568832  0.736499
# 21  0.600372  0.700892
# 22  0.605304  0.870463
# 23  0.603289  0.856703
# 24  0.602676  0.761089
# 25  0.616689  0.741209
# 26  0.620938  0.868130
