# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import json
import numpy 
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import pyarrow
import sys

from datetime import date
from dotenv import load_dotenv
from sqlalchemy import create_engine
from os import path
from typing import List,Dict, Tuple
from collections import defaultdict
pd.set_option("display.max_columns", None)

load_dotenv(verbose=True)
BIGQUERY_CREDENTIALS_PATH = os.environ.get('BIGQUERY_CREDENTIALS_PATH')
engine = create_engine('bigquery://bespoke-financial/ProdMetrcData', credentials_path=os.path.expanduser(BIGQUERY_CREDENTIALS_PATH))

sys.path.append(path.realpath(path.join(os.getcwd(), "../core")))
sys.path.append(path.realpath(path.join(os.getcwd(), "../../src")))

import create_queries
import prepare_data

from bespoke.inventory.analysis.shared import download_util, inventory_types
from bespoke.inventory.analysis import active_inventory_util as util
from bespoke.inventory.analysis import inventory_valuations_util as valuations_util

# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv('all_metrc_gm_0526.csv',index_col=0)

# %%
data
# Out:
#          date    revenue           cogs       margin_$  margin_%  \
# 0     2021-01  291646.25   69820.627134  221825.622866  0.760598
# 1     2021-02  262906.73   85237.307175  177669.422825  0.675789
# 2     2021-03  315154.72   99796.271792  215358.448208  0.683342
# 3     2021-04  329925.48  100825.215287  229100.264713  0.694400
# 4     2021-05  336793.80   98971.770002  237822.029998  0.706135
# ...       ...        ...            ...            ...       ...
# 2676  2022-01   24339.01   11123.403847   13215.606153  0.542980
# 2677  2022-02   24450.82   10430.082937   14020.737063  0.573426
# 2678  2022-03   27920.68   11679.072300   16241.607700  0.581705
# 2679  2022-04   42846.56   19011.597583   23834.962417  0.556286
# 2680  2022-05   49912.73   22003.542342   27909.187658  0.559160
#
#       total_count_incoming  product_count  count_incoming  coverage  \
# 0                   4810.0         2005.0            2805  0.696294
# 1                   5464.0          377.0            5087  0.948611
# 2                   6902.0          159.0            6743  0.951475
# 3                   7081.0          112.0            6969  0.931465
# 4                   7286.0          131.0            7155  0.918326
# ...                    ...            ...             ...       ...
# 2676                 831.0           43.0             788  0.936866
# 2677                 798.0           39.0             759  0.955689
# 2678                 950.0           71.0             879  0.964467
# 2679                2064.0           42.0            2022  0.988979
# 2680                1808.0           34.0            1774  0.987978
#
#       revenue_after_tax  cogs_after_tax  margin_$_after_tax  \
# 0           335393.1875    88672.196461       246720.991039
# 1           302342.7395   108251.380112       194091.359388
# 2           362427.9280   126741.265176       235686.662824
# 3           379414.3020   128048.023414       251366.278586
# 4           387312.8700   125694.147903       261618.722097
# ...                 ...             ...                 ...
# 2676         27989.8615    14126.722885        13863.138615
# 2677         28118.4430    13246.205331        14872.237669
# 2678         32108.7820    14832.421821        17276.360179
# 2679         49273.5440    24144.728931        25128.815069
# 2680         57399.6395    27944.498774        29455.140726
#
#       margin_%_after_tax  gm_past_quarter  gm_past_2quarters  \
# 0               0.735617              NaN                NaN
# 1               0.641958              NaN                NaN
# 2               0.650299         0.706576                NaN
# 3               0.662511         0.684510                NaN
# 4               0.675471         0.694626                NaN
# ...                  ...              ...                ...
# 2676            0.495291         0.626026                NaN
# 2677            0.528914         0.581204           0.604904
# 2678            0.538057         0.566037           0.621341
# 2679            0.509986         0.570473           0.598249
# 2680            0.513159         0.565717           0.573461
#
#       gm_past_3quarters  gm_past_quarter_after_tax  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                   0.675958
# 3                   NaN                   0.651590
# 4                   NaN                   0.662761
# ...                 ...                        ...
# 2676                NaN                   0.587002
# 2677                NaN                   0.537504
# 2678                NaN                   0.520754
# 2679                NaN                   0.525652
# 2680           0.591842                   0.520401
#
#       gm_past_2quarters_after_tax  gm_past_3quarters_after_tax  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 2676                          NaN                          NaN
# 2677                     0.563676                          NaN
# 2678                     0.581829                          NaN
# 2679                     0.556327                          NaN
# 2680                     0.528952                     0.549251
#
#       gm$_past_quarter_after_tax  gm$_past_2quarters_after_tax  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                  225499.671084                           NaN
# 3                  227048.100266                           NaN
# 4                  249557.221169                           NaN
# ...                          ...                           ...
# 2676                16870.717070                           NaN
# 2677                16956.337113                  14568.225700
# 2678                15337.245488                  15937.723007
# 2679                19092.470972                  17981.594021
# 2680                23953.438658                  20454.887885
#
#       gm$_past_3quarters_after_tax company         location  \
# 0                              NaN    99HT  C10-0000279-LIC
# 1                              NaN    99HT  C10-0000279-LIC
# 2                              NaN    99HT  C10-0000279-LIC
# 3                              NaN    99HT  C10-0000279-LIC
# 4                              NaN    99HT  C10-0000279-LIC
# ...                            ...     ...              ...
# 2676                           NaN     VOY  C10-0000802-LIC
# 2677                           NaN     VOY  C10-0000802-LIC
# 2678                           NaN     VOY  C10-0000802-LIC
# 2679                           NaN     VOY  C10-0000802-LIC
# 2680                  17696.630019     VOY  C10-0000802-LIC
#
#                                id company_identifier state
# 0     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 1     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 2     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 3     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 4     ('99HT', 'C10-0000279-LIC')               99HT    CA
# ...                           ...                ...   ...
# 2676   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2677   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2678   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2679   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2680   ('VOY', 'C10-0000802-LIC')                VOY    CA
#
# [2681 rows x 27 columns]

# %%
df_clients = [
'DL',
'DW',
'EMA',
'EMM',
'EMT',
'EMF',
'ST',
'GRG',
'EL',
'VS',
'TT',
'MD',
'DWF',
'GHC',
'SV',
'99HT',
'NECC',
'MPW',
'LBC'
]

# %%
data_client = data[data['company_identifier'].isin(df_clients)]

# %%
data_client['company_identifier'].unique()
# Out:
# array(['99HT', 'DWF', 'DL', 'EL', 'EMA', 'EMF', 'EMM', 'EMT', 'GRG',
#        'GHC', 'LBC', 'MPW', 'MD', 'NECC', 'SV', 'ST', 'DW', 'TT', 'VS'],
#       dtype=object)

# %%
data_client
# Out:
#          date    revenue           cogs       margin_$  margin_%  \
# 0     2021-01  291646.25   69820.627134  221825.622866  0.760598
# 1     2021-02  262906.73   85237.307175  177669.422825  0.675789
# 2     2021-03  315154.72   99796.271792  215358.448208  0.683342
# 3     2021-04  329925.48  100825.215287  229100.264713  0.694400
# 4     2021-05  336793.80   98971.770002  237822.029998  0.706135
# ...       ...        ...            ...            ...       ...
# 2667  2022-01  435566.37  177725.054761  257841.315239  0.591968
# 2668  2022-02  393248.45  215992.402057  177256.047943  0.450748
# 2669  2022-03  420528.44  230621.392647  189907.047353  0.451591
# 2670  2022-04  417415.92  191172.626430  226243.293570  0.542009
# 2671  2022-05  335689.45  163364.799051  172324.650949  0.513345
#
#       total_count_incoming  product_count  count_incoming  coverage  \
# 0                   4810.0         2005.0            2805  0.696294
# 1                   5464.0          377.0            5087  0.948611
# 2                   6902.0          159.0            6743  0.951475
# 3                   7081.0          112.0            6969  0.931465
# 4                   7286.0          131.0            7155  0.918326
# ...                    ...            ...             ...       ...
# 2667               12801.0            0.0           12801  0.922462
# 2668               12013.0          132.0           11881  0.934864
# 2669               13015.0          139.0           12876  0.959525
# 2670               12957.0           89.0           12868  0.905071
# 2671               10723.0           96.0           10627  0.912984
#
#       revenue_after_tax  cogs_after_tax  margin_$_after_tax  \
# 0           335393.1875    88672.196461       246720.991039
# 1           302342.7395   108251.380112       194091.359388
# 2           362427.9280   126741.265176       235686.662824
# 3           379414.3020   128048.023414       251366.278586
# 4           387312.8700   125694.147903       261618.722097
# ...                 ...             ...                 ...
# 2667        500901.3255   225710.819546       275190.505954
# 2668        452235.7175   274310.350612       177925.366888
# 2669        483607.7060   292889.168662       190718.537338
# 2670        480028.3080   242789.235566       237239.072434
# 2671        386042.8675   207473.294795       178569.572705
#
#       margin_%_after_tax  gm_past_quarter  gm_past_2quarters  \
# 0               0.735617              NaN                NaN
# 1               0.641958              NaN                NaN
# 2               0.650299         0.706576                NaN
# 3               0.662511         0.684510                NaN
# 4               0.675471         0.694626                NaN
# ...                  ...              ...                ...
# 2667            0.549391         0.548712           0.519920
# 2668            0.393435         0.520338           0.511786
# 2669            0.394366         0.498103           0.514072
# 2670            0.494219         0.481450           0.515081
# 2671            0.462564         0.502315           0.511327
#
#       gm_past_3quarters  gm_past_quarter_after_tax  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                   0.675958
# 3                   NaN                   0.651590
# 4                   NaN                   0.662761
# ...                 ...                        ...
# 2667           0.486326                   0.501621
# 2668           0.490970                   0.470286
# 2669           0.496658                   0.445731
# 2670           0.507097                   0.427340
# 2671           0.508629                   0.450383
#
#       gm_past_2quarters_after_tax  gm_past_3quarters_after_tax  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 2667                     0.469825                     0.432725
# 2668                     0.460842                     0.437854
# 2669                     0.463366                     0.444135
# 2670                     0.464481                     0.455663
# 2671                     0.460335                     0.457356
#
#       gm$_past_quarter_after_tax  gm$_past_2quarters_after_tax  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                  225499.671084                           NaN
# 3                  227048.100266                           NaN
# 4                  249557.221169                           NaN
# ...                          ...                           ...
# 2667               267500.302738                 273004.565680
# 2668               230143.835160                 254647.974957
# 2669               214611.470060                 245849.495440
# 2670               201960.992220                 234730.647479
# 2671               202175.727492                 216159.781326
#
#       gm$_past_3quarters_after_tax company         location  \
# 0                              NaN    99HT  C10-0000279-LIC
# 1                              NaN    99HT  C10-0000279-LIC
# 2                              NaN    99HT  C10-0000279-LIC
# 3                              NaN    99HT  C10-0000279-LIC
# 4                              NaN    99HT  C10-0000279-LIC
# ...                            ...     ...              ...
# 2667                 256285.182191      VS       402R-00545
# 2668                 252081.562221      VS       402R-00545
# 2669                 250542.216130      VS       402R-00545
# 2670                 249323.374526      VS       402R-00545
# 2671                 237157.225802      VS       402R-00545
#
#                                id company_identifier state
# 0     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 1     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 2     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 3     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 4     ('99HT', 'C10-0000279-LIC')               99HT    CA
# ...                           ...                ...   ...
# 2667         ('VS', '402R-00545')                 VS    CO
# 2668         ('VS', '402R-00545')                 VS    CO
# 2669         ('VS', '402R-00545')                 VS    CO
# 2670         ('VS', '402R-00545')                 VS    CO
# 2671         ('VS', '402R-00545')                 VS    CO
#
# [410 rows x 27 columns]

# %%
margin_distr = data_client.groupby(['date'])['margin_%'].describe().reset_index()
margin_distr['date'] = pd.to_datetime(margin_distr['date'])

# %%
margin_distr[margin_distr['date'] >= '2021-01-01']
# Out:
#          date  count      mean       std       min       25%       50%  \
# 12 2021-01-01   15.0  0.588142  0.129039  0.374260  0.512239  0.625896
# 13 2021-02-01   15.0  0.573114  0.103838  0.393055  0.489807  0.599818
# 14 2021-03-01   16.0  0.556437  0.103607  0.375906  0.492289  0.559886
# 15 2021-04-01   16.0  0.559236  0.110142  0.341996  0.495757  0.576955
# 16 2021-05-01   16.0  0.568153  0.096955  0.388239  0.514654  0.580261
# 17 2021-06-01   16.0  0.559255  0.096536  0.379299  0.523839  0.568190
# 18 2021-07-01   17.0  0.555835  0.092869  0.369410  0.509048  0.568944
# 19 2021-08-01   18.0  0.541328  0.102685  0.286105  0.506818  0.540868
# 20 2021-09-01   19.0  0.544118  0.110898  0.314469  0.508234  0.558778
# 21 2021-10-01   19.0  0.557013  0.083183  0.371533  0.523709  0.588549
# 22 2021-11-01   20.0  0.562222  0.084004  0.363232  0.521218  0.581444
# 23 2021-12-01   20.0  0.572995  0.102743  0.352992  0.523457  0.586965
# 24 2022-01-01   20.0  0.573213  0.096073  0.351497  0.530209  0.594062
# 25 2022-02-01   21.0  0.571765  0.084595  0.401301  0.535407  0.581910
# 26 2022-03-01   21.0  0.564334  0.098948  0.359683  0.518682  0.591531
# 27 2022-04-01   21.0  0.566106  0.079276  0.382144  0.538945  0.579794
# 28 2022-05-01   21.0  0.602781  0.121139  0.403470  0.530318  0.580990
#
#          75%       max
# 12  0.652314  0.810345
# 13  0.665724  0.693440
# 14  0.638797  0.700704
# 15  0.639611  0.722108
# 16  0.642722  0.706135
# 17  0.616269  0.698220
# 18  0.607189  0.703229
# 19  0.603454  0.701284
# 20  0.599427  0.741049
# 21  0.602744  0.696515
# 22  0.621072  0.719094
# 23  0.617164  0.856703
# 24  0.621181  0.761097
# 25  0.627494  0.703362
# 26  0.622364  0.734857
# 27  0.590881  0.720040
# 28  0.633743  0.949110

# %%
data_high_coverage = data[data['coverage'] >= 0.8]

# %%
data_high_coverage
# Out:
#          date    revenue           cogs       margin_$  margin_%  \
# 1     2021-02  262906.73   85237.307175  177669.422825  0.675789
# 2     2021-03  315154.72   99796.271792  215358.448208  0.683342
# 3     2021-04  329925.48  100825.215287  229100.264713  0.694400
# 4     2021-05  336793.80   98971.770002  237822.029998  0.706135
# 5     2021-06  324788.69   98014.813307  226773.876693  0.698220
# ...       ...        ...            ...            ...       ...
# 2676  2022-01   24339.01   11123.403847   13215.606153  0.542980
# 2677  2022-02   24450.82   10430.082937   14020.737063  0.573426
# 2678  2022-03   27920.68   11679.072300   16241.607700  0.581705
# 2679  2022-04   42846.56   19011.597583   23834.962417  0.556286
# 2680  2022-05   49912.73   22003.542342   27909.187658  0.559160
#
#       total_count_incoming  product_count  count_incoming  coverage  \
# 1                   5464.0          377.0            5087  0.948611
# 2                   6902.0          159.0            6743  0.951475
# 3                   7081.0          112.0            6969  0.931465
# 4                   7286.0          131.0            7155  0.918326
# 5                   6860.0          114.0            6746  0.926026
# ...                    ...            ...             ...       ...
# 2676                 831.0           43.0             788  0.936866
# 2677                 798.0           39.0             759  0.955689
# 2678                 950.0           71.0             879  0.964467
# 2679                2064.0           42.0            2022  0.988979
# 2680                1808.0           34.0            1774  0.987978
#
#       revenue_after_tax  cogs_after_tax  margin_$_after_tax  \
# 1           302342.7395   108251.380112       194091.359388
# 2           362427.9280   126741.265176       235686.662824
# 3           379414.3020   128048.023414       251366.278586
# 4           387312.8700   125694.147903       261618.722097
# 5           373506.9935   124478.812900       249028.180600
# ...                 ...             ...                 ...
# 2676         27989.8615    14126.722885        13863.138615
# 2677         28118.4430    13246.205331        14872.237669
# 2678         32108.7820    14832.421821        17276.360179
# 2679         49273.5440    24144.728931        25128.815069
# 2680         57399.6395    27944.498774        29455.140726
#
#       margin_%_after_tax  gm_past_quarter  gm_past_2quarters  \
# 1               0.641958              NaN                NaN
# 2               0.650299         0.706576                NaN
# 3               0.662511         0.684510                NaN
# 4               0.675471         0.694626                NaN
# 5               0.666730         0.699585           0.703081
# ...                  ...              ...                ...
# 2676            0.495291         0.626026                NaN
# 2677            0.528914         0.581204           0.604904
# 2678            0.538057         0.566037           0.621341
# 2679            0.509986         0.570473           0.598249
# 2680            0.513159         0.565717           0.573461
#
#       gm_past_3quarters  gm_past_quarter_after_tax  \
# 1                   NaN                        NaN
# 2                   NaN                   0.675958
# 3                   NaN                   0.651590
# 4                   NaN                   0.662761
# 5                   NaN                   0.668237
# ...                 ...                        ...
# 2676                NaN                   0.587002
# 2677                NaN                   0.537504
# 2678                NaN                   0.520754
# 2679                NaN                   0.525652
# 2680           0.591842                   0.520401
#
#       gm_past_2quarters_after_tax  gm_past_3quarters_after_tax  \
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# 5                        0.672098                          NaN
# ...                           ...                          ...
# 2676                          NaN                          NaN
# 2677                     0.563676                          NaN
# 2678                     0.581829                          NaN
# 2679                     0.556327                          NaN
# 2680                     0.528952                     0.549251
#
#       gm$_past_quarter_after_tax  gm$_past_2quarters_after_tax  \
# 1                            NaN                           NaN
# 2                  225499.671084                           NaN
# 3                  227048.100266                           NaN
# 4                  249557.221169                           NaN
# 5                  254004.393761                 239752.032422
# ...                          ...                           ...
# 2676                16870.717070                           NaN
# 2677                16956.337113                  14568.225700
# 2678                15337.245488                  15937.723007
# 2679                19092.470972                  17981.594021
# 2680                23953.438658                  20454.887885
#
#       gm$_past_3quarters_after_tax company         location  \
# 1                              NaN    99HT  C10-0000279-LIC
# 2                              NaN    99HT  C10-0000279-LIC
# 3                              NaN    99HT  C10-0000279-LIC
# 4                              NaN    99HT  C10-0000279-LIC
# 5                              NaN    99HT  C10-0000279-LIC
# ...                            ...     ...              ...
# 2676                           NaN     VOY  C10-0000802-LIC
# 2677                           NaN     VOY  C10-0000802-LIC
# 2678                           NaN     VOY  C10-0000802-LIC
# 2679                           NaN     VOY  C10-0000802-LIC
# 2680                  17696.630019     VOY  C10-0000802-LIC
#
#                                id company_identifier state
# 1     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 2     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 3     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 4     ('99HT', 'C10-0000279-LIC')               99HT    CA
# 5     ('99HT', 'C10-0000279-LIC')               99HT    CA
# ...                           ...                ...   ...
# 2676   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2677   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2678   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2679   ('VOY', 'C10-0000802-LIC')                VOY    CA
# 2680   ('VOY', 'C10-0000802-LIC')                VOY    CA
#
# [1544 rows x 27 columns]

# %%
margin_distr_high = data_high_coverage.groupby(['date'])['margin_%'].describe().reset_index()
margin_distr_high['date'] = pd.to_datetime(margin_distr_high['date'])

# %%
margin_distr_high[margin_distr_high['date'] >= '2021-01-01']
