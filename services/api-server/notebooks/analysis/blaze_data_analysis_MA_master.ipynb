# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import json
import numpy 
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import pyarrow
import sys
import seaborn as sns

from datetime import date
from dotenv import load_dotenv
from sqlalchemy import create_engine
from os import path
from typing import List,Dict, Tuple
from collections import defaultdict
pd.set_option("display.max_columns", None)

load_dotenv(verbose=True)
BIGQUERY_CREDENTIALS_PATH = os.environ.get('BIGQUERY_CREDENTIALS_PATH')
engine = create_engine('bigquery://bespoke-financial/ProdMetrcData', credentials_path=os.path.expanduser(BIGQUERY_CREDENTIALS_PATH))

sys.path.append(path.realpath(path.join(os.getcwd(), "../core")))
sys.path.append(path.realpath(path.join(os.getcwd(), "../../src")))

import create_queries
import prepare_data

from bespoke.inventory.analysis.shared import download_util, inventory_types
from bespoke.inventory.analysis import active_inventory_util as util
from bespoke.inventory.analysis import inventory_valuations_util as valuations_util
from bespoke.blaze_preapprovals import blaze_uw as blaze_uw

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # ~ Part 1: Create UW data ~
# This part is to read multiple queries to pull all the relevant data needed to perform underwriting.

# %% [markdown]
# ## Gross Margin

# %%
blaze_gm_data = pd.read_sql_query(blaze_uw.create_blaze_gm_query('MA'),engine)
blaze_gm_data['year_month'] = pd.to_datetime(blaze_gm_data['year_month'])

# %%
# Check N of shops to underwrite
blaze_gm_data[['year_month','shopid']].groupby(['year_month']).nunique()
# Out:
#             shopid
# year_month
# 2021-08-31       6
# 2021-09-30       5
# 2021-10-31       6
# 2021-11-30       6
# 2021-12-31       8
# 2022-01-31       8
# 2022-02-28      10
# 2022-03-31       8
# 2022-04-30      10
# 2022-05-31      10
# 2022-06-30      10
# 2022-07-31      11
# 2022-08-31      11
# 2022-09-30      14
# 2022-10-31      13
# 2022-11-30      14
# 2022-12-31      15

# %%
# only underwrite those with more than 5 months of history data
blaze_gm_data_long = blaze_gm_data[blaze_gm_data['month_available'] >= 5]
blaze_gm_data_long[['year_month','shopid']].groupby(['year_month']).nunique()
# Out:
#             shopid
# year_month
# 2021-08-31       5
# 2021-09-30       5
# 2021-10-31       6
# 2021-11-30       6
# 2021-12-31       8
# 2022-01-31       8
# 2022-02-28       9
# 2022-03-31       8
# 2022-04-30      10
# 2022-05-31      10
# 2022-06-30      10
# 2022-07-31      10
# 2022-08-31      10
# 2022-09-30      10
# 2022-10-31      10
# 2022-11-30      10
# 2022-12-31      10

# %%
gm_distr_all = blaze_gm_data_long.groupby(['year_month'])['avg_margin_all'].describe().reset_index()
gm_distr_all.index = pd.to_datetime(gm_distr_all['year_month'])

# %% [markdown]
# ## Monthly GMV change

# %% [markdown]
# ## state website published benchmark

# %%
rev_change_bm_with_weight['year_month'] = gm_distr_all['year_month'].values

# %%
rev_change_bm_with_weight
# Out:
#        0 year_month
# 0    NaN 2021-08-31
# 1  -0.07 2021-09-30
# 2   0.01 2021-10-31
# 3  -0.07 2021-11-30
# 4   0.09 2021-12-31
# 5   0.07 2022-01-31
# 6   0.02 2022-02-28
# 7   0.11 2022-03-31
# 8  -0.01 2022-04-30
# 9  -0.05 2022-05-31
# 10 -0.01 2022-06-30
# 11  0.07 2022-07-31
# 12 -0.02 2022-08-31
# 13 -0.07 2022-09-30
# 14 -0.04 2022-10-31
# 15 -0.04 2022-11-30
# 16   NaN 2022-12-31

# %%
# here for MA we use our own bm, so this part has to be changed manually ...

rev_change_bm_with_weight = pd.DataFrame([numpy.nan,-0.07, 0.01, -0.07, 0.09,0.07,0.02,0.11,-0.01,-0.05,-0.01,0.07,-0.02,-0.07,-0.04,-0.04,numpy.nan])
rev_change_bm_with_weight['year_month'] = gm_distr_all['year_month'].values
rev_change_bm_with_weight['weight'] = [numpy.nan,numpy.nan,numpy.nan,0.04,0.08,0.12,0.2,0.28,0.36,0.44,0.52,0.6,0.68,0.76,0.84,0.92,1]
rev_change_bm_with_weight.columns = ['rev_change_bm','year_month','rev_change_weight']
rev_change_bm_with_weight = rev_change_bm_with_weight.reset_index(drop = True)
rev_change_bm_with_weight
# Out:
#     rev_change_bm year_month  rev_change_weight
# 0             NaN 2021-08-31                NaN
# 1           -0.07 2021-09-30                NaN
# 2            0.01 2021-10-31                NaN
# 3           -0.07 2021-11-30               0.04
# 4            0.09 2021-12-31               0.08
# 5            0.07 2022-01-31               0.12
# 6            0.02 2022-02-28               0.20
# 7            0.11 2022-03-31               0.28
# 8           -0.01 2022-04-30               0.36
# 9           -0.05 2022-05-31               0.44
# 10          -0.01 2022-06-30               0.52
# 11           0.07 2022-07-31               0.60
# 12          -0.02 2022-08-31               0.68
# 13          -0.07 2022-09-30               0.76
# 14          -0.04 2022-10-31               0.84
# 15          -0.04 2022-11-30               0.92
# 16            NaN 2022-12-31               1.00

# %%
blaze_gm_data_long_with_rev  = pd.merge(blaze_gm_data_long,rev_change_bm_with_weight,on=['year_month'], how='inner')
blaze_gm_data_long_with_rev['rev_change_var'] = blaze_gm_data_long_with_rev['rev_change'] - blaze_gm_data_long_with_rev['rev_change_bm']
blaze_gm_data_long_with_rev['rev_change_points'] = [blaze_uw.gmv_change_variance_point_mapping(n) for n in blaze_gm_data_long_with_rev['rev_change_var']]
blaze_gm_data_long_with_rev['rev_change_total'] = blaze_gm_data_long_with_rev['rev_change_points'] * blaze_gm_data_long_with_rev['rev_change_weight']

# %%
blaze_gm_data_long_with_rev[blaze_gm_data_long_with_rev['year_month']=='2022-12-31']
# Out:
#     year_month                    shopid                 companyid  \
# 135 2022-12-31  5fdce3b36c42c608cc9c8b8b  5fdce3b36c42c608cc9c8b73
# 136 2022-12-31  5faf10dda4594c08c922b618  5faf10dda4594c08c922b600
# 137 2022-12-31  5e7e9d34f795d008e7136fe1  5e750658d3980a08d54ddafa
# 138 2022-12-31  5fb5656cd5322c09020a0027  5faf10dda4594c08c922b600
# 139 2022-12-31  610daf318c9aff4915efe183  610daf318c9aff4915efe16a
# 140 2022-12-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 141 2022-12-31  607701db4683fe08ef9f2b44  607701db4683fe08ef9f2b2b
# 142 2022-12-31  609d85d3b6a049435d4faf02  609d85d3b6a049435d4faee9
# 143 2022-12-31  60b913136fc90078bb683ee1  602c09ee9e113008ed666e4a
# 144 2022-12-31  602c09ee9e113008ed666e63  602c09ee9e113008ed666e4a
#
#      rev_pre_tax_post_discount  lag_rev_pre_tax_post_discount       cogs  \
# 135                  409537.45                      313229.31  198890.48
# 136                  378817.29                      280400.53  180526.08
# 137                  468802.61                      427813.25  191382.49
# 138                  828146.02                      688169.09  390795.93
# 139                  170217.70                      136908.95   75149.80
# 140                  248281.57                      192265.80  116427.05
# 141                  433620.64                      352741.27  195939.44
# 142                  459015.89                      364645.93  278416.61
# 143                  580418.59                      456312.77  305661.44
# 144                  546591.47                      424641.90  284332.44
#
#      profit_pre_tax_post_discount  margin_pre_tax_post_discount  \
# 135                     210646.97                      0.514353
# 136                     198291.21                      0.523448
# 137                     277420.12                      0.591763
# 138                     437350.09                      0.528107
# 139                      95067.90                      0.558508
# 140                     131854.52                      0.531068
# 141                     237681.20                      0.548132
# 142                     180599.28                      0.393449
# 143                     274757.15                      0.473378
# 144                     262259.03                      0.479808
#
#      month_available  sum_cogs_3m  avg_margin_3m  avg_margin_6m  \
# 135               17    503997.87       0.535636       0.535954
# 136               17    466541.61       0.525254       0.512104
# 137               17    584051.52       0.600879       0.592161
# 138               17   1124238.73       0.533876       0.528034
# 139               10    214030.37       0.538263       0.527626
# 140                9    305787.05       0.542874       0.540356
# 141               13    544331.81       0.541151       0.531741
# 142               13    714057.68       0.402100       0.419868
# 143               15    760524.72       0.508980       0.504500
# 144               17    730950.52       0.503389       0.500059
#
#      avg_margin_all  rev_change  rev_change_bm  rev_change_weight  \
# 135        0.520750    0.307468            NaN                1.0
# 136        0.492689    0.350986            NaN                1.0
# 137        0.558665    0.095811            NaN                1.0
# 138        0.505312    0.203405            NaN                1.0
# 139        0.437876    0.243291            NaN                1.0
# 140        0.496514    0.291345            NaN                1.0
# 141        0.527765    0.229288            NaN                1.0
# 142        0.419805    0.258799            NaN                1.0
# 143        0.494312    0.271975            NaN                1.0
# 144        0.495201    0.287182            NaN                1.0
#
#      rev_change_var  rev_change_points  rev_change_total
# 135             NaN                NaN               NaN
# 136             NaN                NaN               NaN
# 137             NaN                NaN               NaN
# 138             NaN                NaN               NaN
# 139             NaN                NaN               NaN
# 140             NaN                NaN               NaN
# 141             NaN                NaN               NaN
# 142             NaN                NaN               NaN
# 143             NaN                NaN               NaN
# 144             NaN                NaN               NaN

# %%
blaze_gm_data_long_with_rev[blaze_gm_data_long_with_rev['shopid']== '623e39dfbcd2bd3c1fb82f46']
# Out:
#     year_month                    shopid                 companyid  \
# 60  2022-04-30  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 70  2022-05-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 80  2022-06-30  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 90  2022-07-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 100 2022-08-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 110 2022-09-30  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 120 2022-10-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 130 2022-11-30  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 140 2022-12-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
#
#      rev_pre_tax_post_discount  lag_rev_pre_tax_post_discount       cogs  \
# 60                       53.00                            NaN      43.00
# 70                    39550.45                          53.00   19064.33
# 80                   108733.99                       39550.45   52210.39
# 90                   152905.36                      108733.99   72793.09
# 100                  151454.24                      152905.36   69419.55
# 110                  188028.92                      151454.24   85000.93
# 120                  227504.01                      188028.92  102331.79
# 130                  192265.80                      227504.01   87028.21
# 140                  248281.57                      192265.80  116427.05
#
#      profit_pre_tax_post_discount  margin_pre_tax_post_discount  \
# 60                          10.00                      0.188679
# 70                       20486.12                      0.517974
# 80                       56523.60                      0.519834
# 90                       80112.27                      0.523934
# 100                      82034.69                      0.541647
# 110                     103027.99                      0.547937
# 120                     125172.22                      0.550198
# 130                     105237.59                      0.547355
# 140                     131854.52                      0.531068
#
#      month_available  sum_cogs_3m  avg_margin_3m  avg_margin_6m  \
# 60                 9        43.00       0.188679       0.188679
# 70                 9     19107.33       0.353327       0.353327
# 80                 9     71317.72       0.408829       0.408829
# 90                 9    144067.81       0.520581       0.437605
# 100                9    194423.03       0.528471       0.458414
# 110                9    227213.57       0.537839       0.473334
# 120                9    256752.27       0.546594       0.533587
# 130                9    274360.93       0.548497       0.538484
# 140                9    305787.05       0.542874       0.540356
#
#      avg_margin_all  rev_change  rev_change_bm  rev_change_weight  \
# 60         0.188679         NaN          -0.01               0.36
# 70         0.353327  745.234906          -0.05               0.44
# 80         0.408829    1.749248          -0.01               0.52
# 90         0.437605    0.406233           0.07               0.60
# 100        0.458414   -0.009490          -0.02               0.68
# 110        0.473334    0.241490          -0.07               0.76
# 120        0.484315    0.209942          -0.04               0.84
# 130        0.492195   -0.154891          -0.04               0.92
# 140        0.496514    0.291345            NaN               1.00
#
#      rev_change_var  rev_change_points  rev_change_total
# 60              NaN                NaN               NaN
# 70       745.284906                NaN               NaN
# 80         1.759248                NaN               NaN
# 90         0.336233               10.0               6.0
# 100        0.010510                5.0               3.4
# 110        0.311490               10.0               7.6
# 120        0.249942               10.0               8.4
# 130       -0.114891               -5.0              -4.6
# 140             NaN                NaN               NaN

# %% [markdown]
# ## Inventory

# %%
#need to define the uw date first
uw_date = '2022-12-31'

# %%
inventory_date_list = pd.read_sql_query(blaze_uw.create_blaze_inventory_date_query('MA',uw_date),engine)

# %%
blaze_inv_data_all = pd.read_sql_query(blaze_uw.create_blaze_inventory_query('MA',tuple([str(x) for x in inventory_date_list['date']]),uw_date),engine)
blaze_inv_data_all['year_month'] = pd.to_datetime(blaze_inv_data_all['year_month'])

# %%
#calculate fresh, stale, fresh + stale inventory
fresh_inv = blaze_inv_data_all[blaze_inv_data_all['inventory_group'] == 'fresh'][['year_month','shopid','companyid','inventory']]
stale_inv = blaze_inv_data_all[blaze_inv_data_all['inventory_group'] == 'stale'][['year_month','shopid','companyid','inventory']]
fresh_and_stale_inv = fresh_inv.merge(stale_inv, on = ['shopid','companyid','year_month'],how = 'outer')
fresh_and_stale_inv = fresh_and_stale_inv.fillna(0)
fresh_and_stale_inv.columns = ['year_month','shopid','companyid','inventory_fresh','inventory_stale']
fresh_and_stale_inv['inventory_fresh_and_stale'] = fresh_and_stale_inv['inventory_fresh']  + fresh_and_stale_inv['inventory_stale']

# %%
set(blaze_gm_data['shopid']) - set(fresh_and_stale_inv['shopid'])
# Out:
# {'605cef20813d4c08ebf50c06'}

# %%
#make sure we do not lack inventory data for too many locations (usually 1 or 2 are fine)
set(blaze_gm_data_long_with_rev[blaze_gm_data_long_with_rev['year_month'] == uw_date]['shopid']) - set(fresh_and_stale_inv['shopid'])
# Out:
# set()

# %% [markdown]
# ## Inventory Turnover

# %%
data_joined = pd.merge(blaze_gm_data_long_with_rev,fresh_and_stale_inv,on=['year_month','shopid','companyid'], how='inner')

# %%
data_joined['inventory_turnover'] = data_joined['sum_cogs_3m'] / data_joined['inventory_fresh_and_stale'] * 4
data_joined['year_month'] = pd.to_datetime(data_joined['year_month'])

# %%
# ##some sanity checks
# data_joined[data_joined['year_month'] >= '2021-10-31'].groupby(['year_month'])['inventory_turnover'].describe().reset_index()
# round(data_joined['inventory_turnover'].quantile(0.95),2)

# %% [markdown]
# # ~ Part 2: Start UW ~
# Now that we have all the essential data for UW. We choose the date we want to perform underwriting on and start calculating the KPIs.

# %%
recent = data_joined[data_joined['year_month'] == '2022-12-31']
recent = recent.reset_index(drop = True)

# %%
# check final # of locations to UW
recent[['year_month','shopid']].groupby(['year_month']).nunique()
# Out:
#             shopid
# year_month
# 2022-12-31      10

# %% [markdown]
# ## 1. gm % score

# %%
gm_threshold = [[0.49,0.50,0.51,0.7],[0.49,0.50,0.51,0.7],[0.49,0.50,0.51,0.7]]

# %%
gm_score_data = recent.apply(lambda row: blaze_uw.get_gm_perc_scores(gm_threshold,row['avg_margin_3m'],row['avg_margin_6m'],row['avg_margin_all']),axis = 1)
recent_with_gm = pd.concat([recent, pd.DataFrame([list(y) for y in gm_score_data.values], columns = ['gm_3m_score', 'gm_6m_score','gm_all_score'])],axis=1)

# %% [markdown]
# ## 2. inventory turnover score

# %%
recent_with_gm['turnover_score'] = [10 if (recent_with_gm['inventory_turnover'][i] >= 6 and recent_with_gm['inventory_turnover'][i] <= 26) else 0 for i in range(len(recent_with_gm))]

# %% [markdown]
# ## 3. rev change score

# %%
rev_change_score = blaze_gm_data_long_with_rev[['shopid','rev_change_total']].groupby('shopid').sum().reset_index()

# %%
rev_change_score['rev_change_score'] = [max(min(round(rev_change_score['rev_change_total'][i],2),10),-10) for i in range(len(rev_change_score))]
#rev_change_score.sort_values(by = 'rev_change_total')

# %% [markdown]
# ## 4. gm $ score

# %%
gm_dollar_score = blaze_gm_data_long_with_rev[['shopid','profit_pre_tax_post_discount']].groupby('shopid').mean().reset_index()

# %%
gm_dollar_score['gm_dollar_score'] = [15 if gm_dollar_score['profit_pre_tax_post_discount'][i] >= 200000 else 0 for i in range(len(rev_change_score))]

# %%
recent_with_gm_and_rev_change = pd.merge(recent_with_gm,rev_change_score[['shopid','rev_change_score']],on=['shopid'], how='inner')
#recent_with_gm_and_rev_change

# %% [markdown]
# # ~ Part 3: Final scoring and credit limit & rate calculation ~

# %%
final = pd.merge(recent_with_gm_and_rev_change,gm_dollar_score[['shopid','gm_dollar_score']],on=['shopid'], how='inner')

# %%
final['total_gm_perc_score'] = final['gm_3m_score'] + final['gm_6m_score'] + final['gm_all_score']
final['total_gm_score'] = [min(final['gm_dollar_score'][i]+final['total_gm_perc_score'][i],15) for i in range(len(final))]
final['total_score'] = final['total_gm_score'] + final['rev_change_score'] + final['turnover_score']
final['credit_limit_raw'] = [round(min(final['sum_cogs_3m'][i],final['inventory_fresh'][i]),0) for i in range(len(final))]
final['potential_credit_limit'] = round(final['credit_limit_raw'],-4) 
final['initial_credit_limit'] = final['potential_credit_limit'] / 2

# %%
final
# Out:
#   year_month                    shopid                 companyid  \
# 0 2022-12-31  5fdce3b36c42c608cc9c8b8b  5fdce3b36c42c608cc9c8b73
# 1 2022-12-31  5faf10dda4594c08c922b618  5faf10dda4594c08c922b600
# 2 2022-12-31  5e7e9d34f795d008e7136fe1  5e750658d3980a08d54ddafa
# 3 2022-12-31  5fb5656cd5322c09020a0027  5faf10dda4594c08c922b600
# 4 2022-12-31  610daf318c9aff4915efe183  610daf318c9aff4915efe16a
# 5 2022-12-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 6 2022-12-31  607701db4683fe08ef9f2b44  607701db4683fe08ef9f2b2b
# 7 2022-12-31  609d85d3b6a049435d4faf02  609d85d3b6a049435d4faee9
# 8 2022-12-31  60b913136fc90078bb683ee1  602c09ee9e113008ed666e4a
# 9 2022-12-31  602c09ee9e113008ed666e63  602c09ee9e113008ed666e4a
#
#    rev_pre_tax_post_discount  lag_rev_pre_tax_post_discount       cogs  \
# 0                  409537.45                      313229.31  198890.48
# 1                  378817.29                      280400.53  180526.08
# 2                  468802.61                      427813.25  191382.49
# 3                  828146.02                      688169.09  390795.93
# 4                  170217.70                      136908.95   75149.80
# 5                  248281.57                      192265.80  116427.05
# 6                  433620.64                      352741.27  195939.44
# 7                  459015.89                      364645.93  278416.61
# 8                  580418.59                      456312.77  305661.44
# 9                  546591.47                      424641.90  284332.44
#
#    profit_pre_tax_post_discount  margin_pre_tax_post_discount  \
# 0                     210646.97                      0.514353
# 1                     198291.21                      0.523448
# 2                     277420.12                      0.591763
# 3                     437350.09                      0.528107
# 4                      95067.90                      0.558508
# 5                     131854.52                      0.531068
# 6                     237681.20                      0.548132
# 7                     180599.28                      0.393449
# 8                     274757.15                      0.473378
# 9                     262259.03                      0.479808
#
#    month_available  sum_cogs_3m  avg_margin_3m  avg_margin_6m  avg_margin_all  \
# 0               17    503997.87       0.535636       0.535954        0.520750
# 1               17    466541.61       0.525254       0.512104        0.492689
# 2               17    584051.52       0.600879       0.592161        0.558665
# 3               17   1124238.73       0.533876       0.528034        0.505312
# 4               10    214030.37       0.538263       0.527626        0.437876
# 5                9    305787.05       0.542874       0.540356        0.496514
# 6               13    544331.81       0.541151       0.531741        0.527765
# 7               13    714057.68       0.402100       0.419868        0.419805
# 8               15    760524.72       0.508980       0.504500        0.494312
# 9               17    730950.52       0.503389       0.500059        0.495201
#
#    rev_change  rev_change_bm  rev_change_weight  rev_change_var  \
# 0    0.307468            NaN                1.0             NaN
# 1    0.350986            NaN                1.0             NaN
# 2    0.095811            NaN                1.0             NaN
# 3    0.203405            NaN                1.0             NaN
# 4    0.243291            NaN                1.0             NaN
# 5    0.291345            NaN                1.0             NaN
# 6    0.229288            NaN                1.0             NaN
# 7    0.258799            NaN                1.0             NaN
# 8    0.271975            NaN                1.0             NaN
# 9    0.287182            NaN                1.0             NaN
#
#    rev_change_points  rev_change_total  inventory_fresh  inventory_stale  \
# 0                NaN               NaN    230739.660792      6466.512500
# 1                NaN               NaN    311035.133750     13945.370000
# 2                NaN               NaN    147678.255000      5029.395000
# 3                NaN               NaN    410290.197500     17334.325000
# 4                NaN               NaN    164363.628750      4827.540000
# 5                NaN               NaN    255603.826250     13947.850833
# 6                NaN               NaN    217525.426667     11322.890000
# 7                NaN               NaN    371571.358345     27126.232500
# 8                NaN               NaN    335936.541750      9567.303333
# 9                NaN               NaN    223512.647917      2208.586250
#
#    inventory_fresh_and_stale  inventory_turnover  gm_3m_score  gm_6m_score  \
# 0              237206.173292            8.498900            5            5
# 1              324980.503750            5.742395            5            5
# 2              152707.650000           15.298553            5            5
# 3              427624.522500           10.516130            5            5
# 4              169191.168750            5.060084            5            5
# 5              269551.677083            4.537713            5            5
# 6              228848.316667            9.514281            5            5
# 7              398697.590845            7.163903           -2           -2
# 8              345503.845083            8.804819            5            5
# 9              225721.234167           12.953155            5            5
#
#    gm_all_score  turnover_score  rev_change_score  gm_dollar_score  \
# 0             5              10                10                0
# 1             0               0                10                0
# 2             5              10                10               15
# 3             5              10                10               15
# 4            -2               0                10                0
# 5             0               0                10                0
# 6             5              10                10                0
# 7            -2              10                10                0
# 8             0              10                10                0
# 9             0              10                10               15
#
#    total_gm_perc_score  total_gm_score  total_score  credit_limit_raw  \
# 0                   15              15           35          230740.0
# 1                   10              10           20          311035.0
# 2                   15              15           35          147678.0
# 3                   15              15           35          410290.0
# 4                    8               8           18          164364.0
# 5                   10              10           20          255604.0
# 6                   15              15           35          217525.0
# 7                   -6              -6           14          371571.0
# 8                   10              10           30          335937.0
# 9                   10              15           35          223513.0
#
#    potential_credit_limit  initial_credit_limit
# 0                230000.0              115000.0
# 1                310000.0              155000.0
# 2                150000.0               75000.0
# 3                410000.0              205000.0
# 4                160000.0               80000.0
# 5                260000.0              130000.0
# 6                220000.0              110000.0
# 7                370000.0              185000.0
# 8                340000.0              170000.0
# 9                220000.0              110000.0

# %%
# look at distribution of total score
final['total_score'].describe()
# Out:
# count    10.000000
# mean     27.700000
# std       8.641631
# min      14.000000
# 25%      20.000000
# 50%      32.500000
# 75%      35.000000
# max      35.000000
# Name: total_score, dtype: float64

# %% [markdown]
# # ~ Part 4: Generate pre-approvals ~
# Passing criteria:
# 1. total score >= 30
# 2. GM dollar >= 25K
# 3. Potential credit limit >= 30K

# %%
# per passing criterial above
final_pass = final[(final['total_score'] >= 24)&\
                  (final['profit_pre_tax_post_discount'] >= 25000)&\
                  (final['potential_credit_limit'] >= 30000)]
final_pass = final_pass.reset_index(drop=True)

# %%
final_pass
# Out:
#   year_month                    shopid                 companyid  \
# 0 2022-12-31  5fdce3b36c42c608cc9c8b8b  5fdce3b36c42c608cc9c8b73
# 1 2022-12-31  5e7e9d34f795d008e7136fe1  5e750658d3980a08d54ddafa
# 2 2022-12-31  5fb5656cd5322c09020a0027  5faf10dda4594c08c922b600
# 3 2022-12-31  607701db4683fe08ef9f2b44  607701db4683fe08ef9f2b2b
# 4 2022-12-31  60b913136fc90078bb683ee1  602c09ee9e113008ed666e4a
# 5 2022-12-31  602c09ee9e113008ed666e63  602c09ee9e113008ed666e4a
#
#    rev_pre_tax_post_discount  lag_rev_pre_tax_post_discount       cogs  \
# 0                  409537.45                      313229.31  198890.48
# 1                  468802.61                      427813.25  191382.49
# 2                  828146.02                      688169.09  390795.93
# 3                  433620.64                      352741.27  195939.44
# 4                  580418.59                      456312.77  305661.44
# 5                  546591.47                      424641.90  284332.44
#
#    profit_pre_tax_post_discount  margin_pre_tax_post_discount  \
# 0                     210646.97                      0.514353
# 1                     277420.12                      0.591763
# 2                     437350.09                      0.528107
# 3                     237681.20                      0.548132
# 4                     274757.15                      0.473378
# 5                     262259.03                      0.479808
#
#    month_available  sum_cogs_3m  avg_margin_3m  avg_margin_6m  avg_margin_all  \
# 0               17    503997.87       0.535636       0.535954        0.520750
# 1               17    584051.52       0.600879       0.592161        0.558665
# 2               17   1124238.73       0.533876       0.528034        0.505312
# 3               13    544331.81       0.541151       0.531741        0.527765
# 4               15    760524.72       0.508980       0.504500        0.494312
# 5               17    730950.52       0.503389       0.500059        0.495201
#
#    rev_change  rev_change_bm  rev_change_weight  rev_change_var  \
# 0    0.307468            NaN                1.0             NaN
# 1    0.095811            NaN                1.0             NaN
# 2    0.203405            NaN                1.0             NaN
# 3    0.229288            NaN                1.0             NaN
# 4    0.271975            NaN                1.0             NaN
# 5    0.287182            NaN                1.0             NaN
#
#    rev_change_points  rev_change_total  inventory_fresh  inventory_stale  \
# 0                NaN               NaN    230739.660792      6466.512500
# 1                NaN               NaN    147678.255000      5029.395000
# 2                NaN               NaN    410290.197500     17334.325000
# 3                NaN               NaN    217525.426667     11322.890000
# 4                NaN               NaN    335936.541750      9567.303333
# 5                NaN               NaN    223512.647917      2208.586250
#
#    inventory_fresh_and_stale  inventory_turnover  gm_3m_score  gm_6m_score  \
# 0              237206.173292            8.498900            5            5
# 1              152707.650000           15.298553            5            5
# 2              427624.522500           10.516130            5            5
# 3              228848.316667            9.514281            5            5
# 4              345503.845083            8.804819            5            5
# 5              225721.234167           12.953155            5            5
#
#    gm_all_score  turnover_score  rev_change_score  gm_dollar_score  \
# 0             5              10                10                0
# 1             5              10                10               15
# 2             5              10                10               15
# 3             5              10                10                0
# 4             0              10                10                0
# 5             0              10                10               15
#
#    total_gm_perc_score  total_gm_score  total_score  credit_limit_raw  \
# 0                   15              15           35          230740.0
# 1                   15              15           35          147678.0
# 2                   15              15           35          410290.0
# 3                   15              15           35          217525.0
# 4                   10              10           30          335937.0
# 5                   10              15           35          223513.0
#
#    potential_credit_limit  initial_credit_limit
# 0                230000.0              115000.0
# 1                150000.0               75000.0
# 2                410000.0              205000.0
# 3                220000.0              110000.0
# 4                340000.0              170000.0
# 5                220000.0              110000.0

# %%
final_pass['annual_rate'] = [blaze_uw.calculate_interest_rate(final_pass['total_score'][i],45)[1] for i in range(len(final_pass))]
final_pass['monthly_rate'] = [blaze_uw.calculate_interest_rate(final_pass['total_score'][i],45)[0] for i in range(len(final_pass))]

# %%
# look at the approval rate this month
final_pass.shape[0] / final.shape[0]
# Out:
# 0.6

# %%
final_pass.shape[0]
# Out:
# 6

# %%
final_pass
# Out:
#   year_month                    shopid                 companyid  \
# 0 2022-12-31  5fdce3b36c42c608cc9c8b8b  5fdce3b36c42c608cc9c8b73
# 1 2022-12-31  5e7e9d34f795d008e7136fe1  5e750658d3980a08d54ddafa
# 2 2022-12-31  5fb5656cd5322c09020a0027  5faf10dda4594c08c922b600
# 3 2022-12-31  607701db4683fe08ef9f2b44  607701db4683fe08ef9f2b2b
# 4 2022-12-31  60b913136fc90078bb683ee1  602c09ee9e113008ed666e4a
# 5 2022-12-31  602c09ee9e113008ed666e63  602c09ee9e113008ed666e4a
#
#    rev_pre_tax_post_discount  lag_rev_pre_tax_post_discount       cogs  \
# 0                  409537.45                      313229.31  198890.48
# 1                  468802.61                      427813.25  191382.49
# 2                  828146.02                      688169.09  390795.93
# 3                  433620.64                      352741.27  195939.44
# 4                  580418.59                      456312.77  305661.44
# 5                  546591.47                      424641.90  284332.44
#
#    profit_pre_tax_post_discount  margin_pre_tax_post_discount  \
# 0                     210646.97                      0.514353
# 1                     277420.12                      0.591763
# 2                     437350.09                      0.528107
# 3                     237681.20                      0.548132
# 4                     274757.15                      0.473378
# 5                     262259.03                      0.479808
#
#    month_available  sum_cogs_3m  avg_margin_3m  avg_margin_6m  avg_margin_all  \
# 0               17    503997.87       0.535636       0.535954        0.520750
# 1               17    584051.52       0.600879       0.592161        0.558665
# 2               17   1124238.73       0.533876       0.528034        0.505312
# 3               13    544331.81       0.541151       0.531741        0.527765
# 4               15    760524.72       0.508980       0.504500        0.494312
# 5               17    730950.52       0.503389       0.500059        0.495201
#
#    rev_change  rev_change_bm  rev_change_weight  rev_change_var  \
# 0    0.307468            NaN                1.0             NaN
# 1    0.095811            NaN                1.0             NaN
# 2    0.203405            NaN                1.0             NaN
# 3    0.229288            NaN                1.0             NaN
# 4    0.271975            NaN                1.0             NaN
# 5    0.287182            NaN                1.0             NaN
#
#    rev_change_points  rev_change_total  inventory_fresh  inventory_stale  \
# 0                NaN               NaN    230739.660792      6466.512500
# 1                NaN               NaN    147678.255000      5029.395000
# 2                NaN               NaN    410290.197500     17334.325000
# 3                NaN               NaN    217525.426667     11322.890000
# 4                NaN               NaN    335936.541750      9567.303333
# 5                NaN               NaN    223512.647917      2208.586250
#
#    inventory_fresh_and_stale  inventory_turnover  gm_3m_score  gm_6m_score  \
# 0              237206.173292            8.498900            5            5
# 1              152707.650000           15.298553            5            5
# 2              427624.522500           10.516130            5            5
# 3              228848.316667            9.514281            5            5
# 4              345503.845083            8.804819            5            5
# 5              225721.234167           12.953155            5            5
#
#    gm_all_score  turnover_score  rev_change_score  gm_dollar_score  \
# 0             5              10                10                0
# 1             5              10                10               15
# 2             5              10                10               15
# 3             5              10                10                0
# 4             0              10                10                0
# 5             0              10                10               15
#
#    total_gm_perc_score  total_gm_score  total_score  credit_limit_raw  \
# 0                   15              15           35          230740.0
# 1                   15              15           35          147678.0
# 2                   15              15           35          410290.0
# 3                   15              15           35          217525.0
# 4                   10              10           30          335937.0
# 5                   10              15           35          223513.0
#
#    potential_credit_limit  initial_credit_limit  annual_rate  monthly_rate
# 0                230000.0              115000.0         0.20        0.0167
# 1                150000.0               75000.0         0.20        0.0167
# 2                410000.0              205000.0         0.20        0.0167
# 3                220000.0              110000.0         0.20        0.0167
# 4                340000.0              170000.0         0.21        0.0175
# 5                220000.0              110000.0         0.20        0.0167

# %% [markdown]
# # ~ Part 5: output data ~

# %%
# # # only take the essential columns to output to csv file
# final_pass[['shopid', 'companyid', 'rev_pre_tax_post_discount', 'cogs',
#        'profit_pre_tax_post_discount', 'margin_pre_tax_post_discount',
#        'sum_cogs_3m', 'avg_margin_3m', 'avg_margin_6m', 'avg_margin_all',
#        'inventory_fresh_and_stale', 'inventory_turnover', 'gm_3m_score',
#        'gm_6m_score', 'gm_all_score', 'total_gm_perc_score', 'gm_dollar_score', 'total_gm_score', 'turnover_score', 'rev_change_score',
# 'total_score', 'credit_limit_raw', 'potential_credit_limit', 'initial_credit_limit','annual_rate',
#        'monthly_rate']]

# %% [markdown]
# ## Output the pre-approval list to a csv file
# Always name the csv file as "blaze_ma_MONTH_approval.csv"

# %%
# final_pass[['shopid', 'companyid', 'rev_pre_tax_post_discount', 'cogs',
#        'profit_pre_tax_post_discount', 'margin_pre_tax_post_discount',
#        'sum_cogs_3m', 'avg_margin_3m', 'avg_margin_6m', 'avg_margin_all',
#        'inventory_fresh_and_stale', 'inventory_turnover', 'gm_3m_score',
#        'gm_6m_score', 'gm_all_score', 'total_gm_perc_score', 'gm_dollar_score', 'total_gm_score', 'turnover_score', 'rev_change_score',
# 'total_score', 'credit_limit_raw', 'potential_credit_limit', 'initial_credit_limit','annual_rate',
#        'monthly_rate']].to_csv('blaze_ma_dec_approval.csv')

# %% [markdown]
# ## Output all uw data to a csv file
# Always name the csv file as "blaze_ma_MONTH_all.csv"

# %%
# final[['year_month', 'shopid', 'companyid', 'rev_pre_tax_post_discount', 'cogs', 'profit_pre_tax_post_discount',
#        'margin_pre_tax_post_discount', 'sum_cogs_3m',
#        'avg_margin_3m', 'avg_margin_6m', 'avg_margin_all', 'inventory_fresh_and_stale',
#        'inventory_turnover', 'gm_3m_score', 'gm_6m_score', 'gm_all_score', 'total_gm_perc_score','gm_dollar_score',
#        'total_gm_score','turnover_score', 'rev_change_score',  'total_score', 'credit_limit_raw', 'potential_credit_limit', 'initial_credit_limit']]\
# .to_csv('blaze_ma_dec_all.csv')

# %% [markdown]
# # ~ Part 6: Diff analysis to compare with last month ~

# %%
# read last month's files
#prev_approve = pd.read_csv('blaze_ma_oct_approval.csv',index_col=0)
prev_all = pd.read_csv('blaze_ma_nov_all.csv',index_col=0)

# %%
prev_all
# Out:
#    year_month                    shopid                 companyid  \
# 0  2022-10-31  5fb5656cd5322c09020a0027  5faf10dda4594c08c922b600
# 1  2022-10-31  602c09ee9e113008ed666e63  602c09ee9e113008ed666e4a
# 2  2022-10-31  5faf10dda4594c08c922b618  5faf10dda4594c08c922b600
# 3  2022-10-31  5fdce3b36c42c608cc9c8b8b  5fdce3b36c42c608cc9c8b73
# 4  2022-10-31  5e7e9d34f795d008e7136fe1  5e750658d3980a08d54ddafa
# 5  2022-10-31  610daf318c9aff4915efe183  610daf318c9aff4915efe16a
# 6  2022-10-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
# 7  2022-10-31  60b913136fc90078bb683ee1  602c09ee9e113008ed666e4a
# 8  2022-10-31  609d85d3b6a049435d4faf02  609d85d3b6a049435d4faee9
# 9  2022-10-31  607701db4683fe08ef9f2b44  607701db4683fe08ef9f2b2b
#
#    rev_pre_tax_post_discount       cogs  profit_pre_tax_post_discount  \
# 0                  941125.62  437667.52                     503458.10
# 1                  517496.38  251999.86                     265496.52
# 2                  337211.23  161323.42                     175887.81
# 3                  380065.11  168858.98                     211206.13
# 4                  604509.33  239024.96                     365484.37
# 5                  166121.16   77877.82                      88243.34
# 6                  238457.73  105636.53                     132821.20
# 7                  530425.51  248635.27                     281790.24
# 8                  398911.22  227042.19                     171869.03
# 9                  421060.39  194619.58                     226440.81
#
#    margin_pre_tax_post_discount  sum_cogs_3m  avg_margin_2m  avg_margin_3m  \
# 0                      0.534953   1435174.27       0.531575       0.531181
# 1                      0.513040    755322.35       0.502620       0.501870
# 2                      0.521595    512114.76       0.516592       0.517596
# 3                      0.555710    502076.65       0.549431       0.548800
# 4                      0.604597    791179.75       0.599181       0.594942
# 5                      0.531199    223910.36       0.532557       0.536044
# 6                      0.557001    288509.10       0.555421       0.554925
# 7                      0.531253    719671.18       0.515225       0.512478
# 8                      0.430845    547276.57       0.461421       0.454801
# 9                      0.537787    625605.73       0.533178       0.530389
#
#    avg_margin_6m  avg_margin_all  inventory_fresh_and_stale  \
# 0       0.519522        0.502901              359163.921000
# 1       0.504403        0.496247              206025.113000
# 2       0.502646        0.491483              246557.779219
# 3       0.537614        0.525731              243417.557000
# 4       0.582123        0.554735              177139.623167
# 5       0.518130        0.420323              123983.278000
# 6       0.544958        0.494061              184230.271333
# 7       0.502954        0.495582              263765.440667
# 8       0.431704        0.432142              287106.939667
# 9       0.524699        0.528190              275401.663000
#
#    inventory_turnover  gm_3m_score  gm_6m_score  gm_all_score  \
# 0           15.983502            5            5             5
# 1           14.664666            5            5             0
# 2            8.308231            5            5             0
# 3            8.250459            5            5             5
# 4           17.865675            5            5             5
# 5            7.223889            5            5            -2
# 6            6.264098            5            5             0
# 7           10.913806            5            5             0
# 8            7.624707           -2           -2            -2
# 9            9.086448            5            5             5
#
#    total_gm_perc_score  gm_dollar_score  total_gm_score  turnover_score  \
# 0                   15               15              15              10
# 1                   10               15              15              10
# 2                   10                0              10              10
# 3                   15                0              15              10
# 4                   15               15              15              10
# 5                    8                0               8              10
# 6                   10                0              10              10
# 7                   10                0              10              10
# 8                   -6                0              -6              10
# 9                   15                0              15              10
#
#    rev_change_score  total_score  credit_limit_raw  potential_credit_limit  \
# 0              10.0         35.0          355654.0                360000.0
# 1              10.0         35.0          200066.0                200000.0
# 2              10.0         30.0          232326.0                230000.0
# 3              10.0         35.0          235230.0                240000.0
# 4              -1.4         23.6          155182.0                160000.0
# 5              10.0         28.0          117398.0                120000.0
# 6              10.0         30.0          180317.0                180000.0
# 7              10.0         30.0          251272.0                250000.0
# 8              10.0         14.0          269630.0                270000.0
# 9              10.0         35.0          236329.0                240000.0
#
#    initial_credit_limit
# 0              180000.0
# 1              100000.0
# 2              115000.0
# 3              120000.0
# 4               80000.0
# 5               60000.0
# 6               90000.0
# 7              125000.0
# 8              135000.0
# 9              120000.0

# %%
prev_approve = prev_all[prev_all['total_score'] > 24]

# %%
# newly approved this month
newly_added_list = list(set(final_pass['shopid']) - set(prev_approve['shopid']))
final_pass[final_pass['shopid'].isin(newly_added_list)][['shopid','total_score']].sort_values(by = 'shopid')
# Out:
#                      shopid  total_score
# 1  5e7e9d34f795d008e7136fe1           35

# %%
# how they scored last month?
prev_all[prev_all['shopid'].isin(newly_added_list)][['shopid','total_score']].sort_values(by = 'shopid')
# Out:
#                      shopid  total_score
# 4  5e7e9d34f795d008e7136fe1         23.6

# %%
# dropoffs
dropoff_lsit = list(set(prev_approve['shopid']) - set(final_pass['shopid']))

# %%
final[final['shopid'].isin(dropoff_lsit)]
# Out:
#   year_month                    shopid                 companyid  \
# 1 2022-12-31  5faf10dda4594c08c922b618  5faf10dda4594c08c922b600
# 4 2022-12-31  610daf318c9aff4915efe183  610daf318c9aff4915efe16a
# 5 2022-12-31  623e39dfbcd2bd3c1fb82f46  623e39dfbcd2bd3c1fb82f2c
#
#    rev_pre_tax_post_discount  lag_rev_pre_tax_post_discount       cogs  \
# 1                  378817.29                      280400.53  180526.08
# 4                  170217.70                      136908.95   75149.80
# 5                  248281.57                      192265.80  116427.05
#
#    profit_pre_tax_post_discount  margin_pre_tax_post_discount  \
# 1                     198291.21                      0.523448
# 4                      95067.90                      0.558508
# 5                     131854.52                      0.531068
#
#    month_available  sum_cogs_3m  avg_margin_3m  avg_margin_6m  avg_margin_all  \
# 1               17    466541.61       0.525254       0.512104        0.492689
# 4               10    214030.37       0.538263       0.527626        0.437876
# 5                9    305787.05       0.542874       0.540356        0.496514
#
#    rev_change  rev_change_bm  rev_change_weight  rev_change_var  \
# 1    0.350986            NaN                1.0             NaN
# 4    0.243291            NaN                1.0             NaN
# 5    0.291345            NaN                1.0             NaN
#
#    rev_change_points  rev_change_total  inventory_fresh  inventory_stale  \
# 1                NaN               NaN     311035.13375     13945.370000
# 4                NaN               NaN     164363.62875      4827.540000
# 5                NaN               NaN     255603.82625     13947.850833
#
#    inventory_fresh_and_stale  inventory_turnover  gm_3m_score  gm_6m_score  \
# 1              324980.503750            5.742395            5            5
# 4              169191.168750            5.060084            5            5
# 5              269551.677083            4.537713            5            5
#
#    gm_all_score  turnover_score  rev_change_score  gm_dollar_score  \
# 1             0               0                10                0
# 4            -2               0                10                0
# 5             0               0                10                0
#
#    total_gm_perc_score  total_gm_score  total_score  credit_limit_raw  \
# 1                   10              10           20          311035.0
# 4                    8               8           18          164364.0
# 5                   10              10           20          255604.0
#
#    potential_credit_limit  initial_credit_limit
# 1                310000.0              155000.0
# 4                160000.0               80000.0
# 5                260000.0              130000.0

# %% [markdown]
# # ~ Part 7: Summary stats ~

# %%
print('Total number of shop to UW: ' + str(len(final))+ ' (have at least 6m of data)')
print('Total number of shops approved: ' + str(len(final_pass)))
print('The approval rate is: ' + str(round(len(final_pass)/len(final),2)))
print('Total Final Limit rounded: '+ str(sum(final_pass['potential_credit_limit'])))
print('Average Monthly Rate: ' + str(numpy.mean(final_pass['monthly_rate'])))
# Out:
# Total number of shop to UW: 10 (have at least 6m of data)
# Total number of shops approved: 6
# The approval rate is: 0.6
# Total Final Limit rounded: 1570000.0
# Average Monthly Rate: 0.016833333333333336

# %% [markdown]
# # ~ scatch, please ignore ~

# %%
# gm_distr_6m = blaze_gm_data_long.groupby(['year_month'])['avg_margin_6m'].describe().reset_index()
# gm_distr_6m.index = pd.to_datetime(gm_distr_6m['year_month'])
# gm_distr_6m
# round(gm_distr_6m[['25%','50%','75%']].mean(),2)
# round(blaze_gm_data_long['avg_margin_6m'].quantile(0.95),2)

# %%
# gm_distr_all = blaze_gm_data_long.groupby(['year_month'])['avg_margin_all'].describe().reset_index()
# gm_distr_all.index = pd.to_datetime(gm_distr_all['year_month'])
# round(gm_distr_all,3)
# round(gm_distr_all[['25%','50%','75%']].mean(),2)
# round(blaze_gm_data_long['avg_margin_all'].quantile(0.95),2)
