# %%
import json
import pandas

# %%
raw_incoming_transfer_packages_dataframe = pandas.read_excel('data/metrc_transfer_packages_manifest_number_0002185597.xlsx', header=0)
raw_incoming_transfer_packages_dataframe.columns
# Out:
# /Users/warren/venvs/bespoke/lib/python3.7/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['transfer_row_id', 'delivery_row_id', 'package_row_id', 'delivery_type',
#        'manifest_number', 'created_date', 'received_datetime',
#        'shipper_facility_license_number', 'shipper_facility_name',
#        'recipient_facility_license_number', 'recipient_facility_name',
#        'shipment_type_name', 'shipment_transaction_type', 'package_id',
#        'package_label', 'type', 'product_category_name', 'product_name',
#        'shipper_wholesale_price', 'shipped_quantity', 'lab_results_status'],
#       dtype='object')

# %%
raw_sales_transactions_dataframe = pandas.read_excel('data/royal/royal_apothecary_sales_transactions_20210101_20210905.xlsx', header=0)
raw_sales_transactions_dataframe.columns
# Out:
# Index(['date_type', 'id', 'last_modified_at', 'receipt_id', 'receipt_number',
#        'receipt_type', 'sales_customer_type', 'sales_datetime',
#        'total_packages', 'total_price', 'tx_type', 'tx_package_id',
#        'tx_package_label', 'tx_product_name', 'tx_product_category_name',
#        'tx_unit_of_measure', 'tx_quantity_sold', 'tx_total_price'],
#       dtype='object')

# %%
incoming_transfer_packages_dataframe = raw_incoming_transfer_packages_dataframe[[
#     'date_type',
#     'transfer_row_id',
#     'delivery_row_id',
#     'package_row_id',
    'delivery_type',
    'manifest_number',
    'created_date',
    'received_datetime',
    'shipper_facility_license_number',
    'shipper_facility_name',
    'recipient_facility_license_number',
    'recipient_facility_name',
    'shipment_type_name',
    'shipment_transaction_type',
    'package_id',
    'package_label',
    'type',
    'product_category_name',
    'product_name',
    'shipper_wholesale_price',
    'shipped_quantity',
    'lab_results_status',
    # TODO: payload
]]
sales_transactions_dataframe = raw_sales_transactions_dataframe[[
#     'date_type',
#     'id',
    'receipt_id',
    'receipt_number',
    'receipt_type',
    'sales_customer_type',
    'sales_datetime', # IMPORTANT
    'total_packages',
    'total_price',
    'tx_type',
    'tx_package_id',
    'tx_package_label',
    'tx_product_name',
    'tx_product_category_name',
    'tx_unit_of_measure',
    'tx_quantity_sold',
    'tx_total_price',
]]
sales_transactions_dataframe = sales_transactions_dataframe.rename(columns={'tx_package_id': 'package_id'})

# %%
fn = lambda row: f'{row.shipper_facility_name} ({row.shipper_facility_license_number})'
col = incoming_transfer_packages_dataframe.apply(fn, axis=1)
incoming_transfer_packages_dataframe = incoming_transfer_packages_dataframe.assign(shipper_facility=col.values)

fn = lambda row: f'{row.created_date.year}-{"0" if row.created_date.month < 10 else ""}{row.created_date.month}'
col = incoming_transfer_packages_dataframe.apply(fn, axis=1)
incoming_transfer_packages_dataframe = incoming_transfer_packages_dataframe.assign(created_month=col.values)

# %%
incoming_transfer_packages_dataframe
# Out:
#         delivery_type  manifest_number created_date   received_datetime  \
# 0   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 1   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 2   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 3   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 4   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 5   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 6   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 7   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 8   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 9   OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 10  OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 11  OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
# 12  OUTGOING_TO_PAYOR          2185597   2021-07-14 2021-07-15 22:52:21
#
#    shipper_facility_license_number   shipper_facility_name  \
# 0                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 1                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 2                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 3                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 4                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 5                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 6                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 7                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 8                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 9                  C11-0000578-LIC  9701 ENTERPRISES, INC.
# 10                 C11-0000578-LIC  9701 ENTERPRISES, INC.
# 11                 C11-0000578-LIC  9701 ENTERPRISES, INC.
# 12                 C11-0000578-LIC  9701 ENTERPRISES, INC.
#
#    recipient_facility_license_number  recipient_facility_name  \
# 0                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 1                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 2                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 3                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 4                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 5                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 6                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 7                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 8                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 9                    C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 10                   C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 11                   C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
# 12                   C10-0000596-LIC  ROYAL APOTHECARY L.L.C.
#
#     shipment_type_name shipment_transaction_type  package_id  \
# 0   Wholesale Manifest                 Wholesale    16037978
# 1   Wholesale Manifest                 Wholesale    16037977
# 2   Wholesale Manifest                 Wholesale    16037982
# 3   Wholesale Manifest                 Wholesale    16037981
# 4   Wholesale Manifest                 Wholesale    16037979
# 5   Wholesale Manifest                 Wholesale    16037980
# 6   Wholesale Manifest                 Wholesale    16037984
# 7   Wholesale Manifest                 Wholesale    16037983
# 8   Wholesale Manifest                 Wholesale    16037985
# 9   Wholesale Manifest                 Wholesale    16037989
# 10  Wholesale Manifest                 Wholesale    16037986
# 11  Wholesale Manifest                 Wholesale    16037988
# 12  Wholesale Manifest                 Wholesale    16037987
#
#                package_label               type  \
# 0   1A4060300006023000094676  transfer_outgoing
# 1   1A4060300006023000094675  transfer_outgoing
# 2   1A4060300006023000094680  transfer_outgoing
# 3   1A4060300006023000094679  transfer_outgoing
# 4   1A4060300006023000094677  transfer_outgoing
# 5   1A4060300006023000094678  transfer_outgoing
# 6   1A4060300006023000094682  transfer_outgoing
# 7   1A4060300006023000094681  transfer_outgoing
# 8   1A4060300006023000094683  transfer_outgoing
# 9   1A4060300006023000094687  transfer_outgoing
# 10  1A4060300006023000094684  transfer_outgoing
# 11  1A4060300006023000094686  transfer_outgoing
# 12  1A4060300006023000094685  transfer_outgoing
#
#                product_category_name  \
# 0    Flower (packaged eighth - each)
# 1   Flower (packaged quarter - each)
# 2             Edible (weight - each)
# 3    Flower (packaged eighth - each)
# 4    Flower (packaged eighth - each)
# 5    Flower (packaged eighth - each)
# 6    Flower (packaged eighth - each)
# 7             Edible (weight - each)
# 8    Flower (packaged eighth - each)
# 9             Edible (weight - each)
# 10            Edible (weight - each)
# 11    Vape Cartridge (weight - each)
# 12            Edible (weight - each)
#
#                                          product_name  \
# 0   Cabana Flower - Platinum Gelato - 3.5g / Case ...
# 1           Cabana Flower - Afgooey - 7g / Case of 32
# 2   Serra Gumdrops CBD : THC - Relaxation 1:10 Spi...
# 3     Korova Flower - Magic Melon - 3.5g / Case of 32
# 4        Korova Flower - Big Drip - 3.5g / Case of 32
# 5      Korova Flower - Blue Dream - 3.5G / Case of 32
# 6    Sticks Flower - 1n87 Cookies - 3.5g / Case of 40
# 7   Serra Gumdrops THC - Happiness Triple Berry - ...
# 8   Unrivaled Flower - Synchronicity - 3.5g / Case...
# 9   Trade Sample Korova Mini Dips THC - Matcha Dip...
# 10  Trade Sample Serra Gumdrops CBD : THC - Relaxa...
# 11  Trade Sample Sticks Live Resin Carts THC - Gor...
# 12  Trade Sample Serra Gumdrops THC - Happiness Tr...
#
#     shipper_wholesale_price  shipped_quantity lab_results_status  \
# 0                    527.00                32            unknown
# 1                    819.00                32            unknown
# 2                     75.00                10            unknown
# 3                    708.75                32            unknown
# 4                    708.75                32            unknown
# 5                    312.96                32            unknown
# 6                    434.50                40            unknown
# 7                     75.00                10            unknown
# 8                   1778.00                64            unknown
# 9                    300.00               300            unknown
# 10                     0.05                 5            unknown
# 11                    30.00                30            unknown
# 12                     0.05                 5            unknown
#
#                             shipper_facility created_month
# 0   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 1   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 2   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 3   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 4   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 5   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 6   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 7   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 8   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 9   9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 10  9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 11  9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07
# 12  9701 ENTERPRISES, INC. (C11-0000578-LIC)       2021-07

# %%
fn = lambda row: f'{row.sales_datetime.year}-{"0" if row.sales_datetime.month < 10 else ""}{row.sales_datetime.month}'
col = sales_transactions_dataframe.apply(fn, axis=1)
sales_transactions_dataframe = sales_transactions_dataframe.assign(sales_month=col.values)

fn = lambda row: f'{row.sales_datetime.year}-{"0" if row.sales_datetime.month < 10 else ""}{row.sales_datetime.month}-{"0" if row.sales_datetime.day < 10 else ""}{row.sales_datetime.day}'
col = sales_transactions_dataframe.apply(fn, axis=1)
sales_transactions_dataframe = sales_transactions_dataframe.assign(sales_date=col.values)

# %%
sales_transactions_dataframe
# Out:
#         receipt_id  receipt_number receipt_type sales_customer_type  \
# 0      127450152.0       127450152       active            Consumer
# 1      127450152.0       127450152       active            Consumer
# 2      127449768.0       127449768       active            Consumer
# 3      127449768.0       127449768       active            Consumer
# 4      127447355.0       127447355       active            Consumer
# ...            ...             ...          ...                 ...
# 54164   70686157.0        70686157       active            Consumer
# 54165   70685842.0        70685842       active            Consumer
# 54166   70685842.0        70685842       active            Consumer
# 54167   70685535.0        70685535       active            Consumer
# 54168   70682699.0        70682699       active            Consumer
#
#                sales_datetime  total_packages  total_price tx_type  \
# 0     2021-09-06 20:44:17.890               2         22.5  active
# 1     2021-09-06 20:44:17.890               2         22.5  active
# 2     2021-09-06 20:42:04.480               2         70.0  active
# 3     2021-09-06 20:42:04.480               2         70.0  active
# 4     2021-09-06 20:29:27.250               1         45.0  active
# ...                       ...             ...          ...     ...
# 54164 2021-01-02 10:22:29.860               1          5.4  active
# 54165 2021-01-02 10:20:21.890               2         72.0  active
# 54166 2021-01-02 10:20:21.890               2         72.0  active
# 54167 2021-01-02 10:18:18.930               1         18.0  active
# 54168 2021-01-02 09:58:35.860               1         15.3  active
#
#        package_id          tx_package_label  \
# 0      13400831.0  1A406030000A2F5000005662
# 1       8476991.0  1A406030000A2F5000002402
# 2      17476768.0  1A406030000390D000021830
# 3      15593615.0  1A4060300006027000091492
# 4      16892485.0  1A406030002E7C2000000027
# ...           ...                       ...
# 54164  10107769.0  1A4060300003D59000014640
# 54165   9812957.0  1A406030000A3C3000028648
# 54166   9813136.0  1A406030000A3C3000028651
# 54167   9821095.0  1A4060300009FE9000020507
# 54168  10107839.0  1A4060300003D59000014639
#
#                                          tx_product_name  \
# 0                     Major 6.7oz Beverage Pink Lemonade
# 1      Sorse Major Volcanic Orange Mango Beverage 6.7...
# 2      MAADF02435 Bloom Sun Grown Flower 22.4% True O...
# 3       Alien Cookies - 1g Concentrates Live Resin Sauce
# 4                             Beary OG 1g Vape Cartridge
# ...                                                  ...
# 54164  Cali Flwr Farms - Cali Gas OG (1 GM Flower) (#...
# 54165      Lemonnade | NYC Haze | 3.5g | Flower | Indoor
# 54166   Cookies | Red Vines | 1g | Flower | Indoor | Bag
# 54167  West Coast Treez - Dry Flower - INDICA - 3.5g ...
# 54168  Cali Flwr Farms - Cali Berry (3.5 GM Flower) (...
#
#                 tx_product_category_name tx_unit_of_measure  tx_quantity_sold  \
# 0                 Edible (volume - each)               Each               1.0
# 1                 Edible (volume - each)               Each               1.0
# 2          Flower (packaged gram - each)               Each               1.0
# 3      Other Concentrate (weight - each)               Each               1.0
# 4         Vape Cartridge (weight - each)               Each               1.0
# ...                                  ...                ...               ...
# 54164                             Flower              Grams               1.0
# 54165    Flower (packaged eighth - each)               Each               1.0
# 54166      Flower (packaged gram - each)               Each               1.0
# 54167                             Flower              Grams               3.5
# 54168                             Flower              Grams               3.5
#
#        tx_total_price sales_month  sales_date
# 0               11.25     2021-09  2021-09-06
# 1               11.25     2021-09  2021-09-06
# 2               30.00     2021-09  2021-09-06
# 3               40.00     2021-09  2021-09-06
# 4               45.00     2021-09  2021-09-06
# ...               ...         ...         ...
# 54164            5.40     2021-01  2021-01-02
# 54165           55.80     2021-01  2021-01-02
# 54166           16.20     2021-01  2021-01-02
# 54167           18.00     2021-01  2021-01-02
# 54168           15.30     2021-01  2021-01-02
#
# [54169 rows x 17 columns]

# %%
result_dataframe = incoming_transfer_packages_dataframe.set_index('package_id').join(sales_transactions_dataframe.set_index('package_id'), on='package_id', how='inner', lsuffix='_l', rsuffix='_r')
result_dataframe
# Out:
#                 delivery_type  manifest_number created_date  \
# package_id
# 16037978.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# 16037978.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# 16037978.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# 16037978.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# 16037978.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# ...                       ...              ...          ...
# 16037989.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# 16037989.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# 16037989.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# 16037989.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
# 16037989.0  OUTGOING_TO_PAYOR          2185597   2021-07-14
#
#              received_datetime shipper_facility_license_number  \
# package_id
# 16037978.0 2021-07-15 22:52:21                 C11-0000578-LIC
# 16037978.0 2021-07-15 22:52:21                 C11-0000578-LIC
# 16037978.0 2021-07-15 22:52:21                 C11-0000578-LIC
# 16037978.0 2021-07-15 22:52:21                 C11-0000578-LIC
# 16037978.0 2021-07-15 22:52:21                 C11-0000578-LIC
# ...                        ...                             ...
# 16037989.0 2021-07-15 22:52:21                 C11-0000578-LIC
# 16037989.0 2021-07-15 22:52:21                 C11-0000578-LIC
# 16037989.0 2021-07-15 22:52:21                 C11-0000578-LIC
# 16037989.0 2021-07-15 22:52:21                 C11-0000578-LIC
# 16037989.0 2021-07-15 22:52:21                 C11-0000578-LIC
#
#              shipper_facility_name recipient_facility_license_number  \
# package_id
# 16037978.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# 16037978.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# 16037978.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# 16037978.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# 16037978.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# ...                            ...                               ...
# 16037989.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# 16037989.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# 16037989.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# 16037989.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
# 16037989.0  9701 ENTERPRISES, INC.                   C10-0000596-LIC
#
#             recipient_facility_name  shipment_type_name  \
# package_id
# 16037978.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# 16037978.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# 16037978.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# 16037978.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# 16037978.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# ...                             ...                 ...
# 16037989.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# 16037989.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# 16037989.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# 16037989.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
# 16037989.0  ROYAL APOTHECARY L.L.C.  Wholesale Manifest
#
#            shipment_transaction_type  ... total_price tx_type  \
# package_id                            ...
# 16037978.0                 Wholesale  ...       96.00  active
# 16037978.0                 Wholesale  ...       40.00  active
# 16037978.0                 Wholesale  ...       72.00  active
# 16037978.0                 Wholesale  ...       40.00  active
# 16037978.0                 Wholesale  ...       72.00  active
# ...                              ...  ...         ...     ...
# 16037989.0                 Wholesale  ...       22.95  active
# 16037989.0                 Wholesale  ...      131.40  active
# 16037989.0                 Wholesale  ...       72.41  active
# 16037989.0                 Wholesale  ...       38.25  active
# 16037989.0                 Wholesale  ...       43.80  active
#
#                     tx_package_label  \
# package_id
# 16037978.0  1A4060300006023000094676
# 16037978.0  1A4060300006023000094676
# 16037978.0  1A4060300006023000094676
# 16037978.0  1A4060300006023000094676
# 16037978.0  1A4060300006023000094676
# ...                              ...
# 16037989.0  1A4060300006023000094687
# 16037989.0  1A4060300006023000094687
# 16037989.0  1A4060300006023000094687
# 16037989.0  1A4060300006023000094687
# 16037989.0  1A4060300006023000094687
#
#                                               tx_product_name  \
# package_id
# 16037978.0  Cabana Flower - Platinum Gelato - 3.5g / Case ...
# 16037978.0  Cabana Flower - Platinum Gelato - 3.5g / Case ...
# 16037978.0  Cabana Flower - Platinum Gelato - 3.5g / Case ...
# 16037978.0  Cabana Flower - Platinum Gelato - 3.5g / Case ...
# 16037978.0  Cabana Flower - Platinum Gelato - 3.5g / Case ...
# ...                                                       ...
# 16037989.0  Trade Sample Korova Mini Dips THC - Matcha Dip...
# 16037989.0  Trade Sample Korova Mini Dips THC - Matcha Dip...
# 16037989.0  Trade Sample Korova Mini Dips THC - Matcha Dip...
# 16037989.0  Trade Sample Korova Mini Dips THC - Matcha Dip...
# 16037989.0  Trade Sample Korova Mini Dips THC - Matcha Dip...
#
#                    tx_product_category_name  tx_unit_of_measure  \
# package_id
# 16037978.0  Flower (packaged eighth - each)                Each
# 16037978.0  Flower (packaged eighth - each)                Each
# 16037978.0  Flower (packaged eighth - each)                Each
# 16037978.0  Flower (packaged eighth - each)                Each
# 16037978.0  Flower (packaged eighth - each)                Each
# ...                                     ...                 ...
# 16037989.0           Edible (weight - each)                Each
# 16037989.0           Edible (weight - each)                Each
# 16037989.0           Edible (weight - each)                Each
# 16037989.0           Edible (weight - each)                Each
# 16037989.0           Edible (weight - each)                Each
#
#            tx_quantity_sold tx_total_price sales_month  sales_date
# package_id
# 16037978.0              1.0          36.00     2021-09  2021-09-06
# 16037978.0              1.0          40.00     2021-08  2021-08-31
# 16037978.0              1.0          40.00     2021-08  2021-08-30
# 16037978.0              1.0          40.00     2021-08  2021-08-28
# 16037978.0              1.0          40.00     2021-08  2021-08-28
# ...                     ...            ...         ...         ...
# 16037989.0              1.0          14.45     2021-08  2021-08-31
# 16037989.0              1.0          15.30     2021-08  2021-08-12
# 16037989.0              2.0          29.31     2021-08  2021-08-05
# 16037989.0              1.0          14.45     2021-07  2021-07-27
# 16037989.0              1.0          10.20     2021-07  2021-07-16
#
# [172 rows x 35 columns]

# %%
result_dataframe.columns
# Out:
# Index(['delivery_type', 'manifest_number', 'created_date', 'received_datetime',
#        'shipper_facility_license_number', 'shipper_facility_name',
#        'recipient_facility_license_number', 'recipient_facility_name',
#        'shipment_type_name', 'shipment_transaction_type', 'package_label',
#        'type', 'product_category_name', 'product_name',
#        'shipper_wholesale_price', 'shipped_quantity', 'lab_results_status',
#        'shipper_facility', 'created_month', 'receipt_id', 'receipt_number',
#        'receipt_type', 'sales_customer_type', 'sales_datetime',
#        'total_packages', 'total_price', 'tx_type', 'tx_package_label',
#        'tx_product_name', 'tx_product_category_name', 'tx_unit_of_measure',
#        'tx_quantity_sold', 'tx_total_price', 'sales_month', 'sales_date'],
#       dtype='object')

# %%
limited_result_dataframe = result_dataframe[[
#     'manifest_number',
    'package_label',
    'created_month',
    'created_date',
    'received_datetime',
    'shipper_facility',
    'shipper_facility_license_number',
    'shipper_facility_name',
    'shipped_quantity',
    'sales_month',
    'sales_date',
    'sales_datetime',
    'tx_product_name',
    'tx_product_category_name',
    'tx_unit_of_measure',
    'tx_quantity_sold',
    'tx_total_price',
]]
limited_result_dataframe = limited_result_dataframe.sort_values('sales_date', ascending=False)

# %%
from datetime import datetime

def compute_sell_through_for_package_label_records(package_label_records):
    created_date = None
    received_datetime = None
    shipped_quantity = None
    product_category_name = None
    product_name = None
    
    # As of what date is X% of package is sold?
    percent_25_date = None
    percent_50_date = None
    percent_75_date = None
    percent_90_date = None
    percent_100_date = None
    
    # How many days until X% of package is sold?
    percent_25_days_count = None
    percent_50_days_count = None
    percent_75_days_count = None
    percent_90_days_count = None
    percent_100_days_count = None
    
    # As of date when X% of package is sold, on average how many units are sold per day?
    percent_25_days_count_norm = None
    percent_50_days_count_norm = None
    percent_75_days_count_norm = None
    percent_90_days_count_norm = None
    percent_100_days_count_norm = None

    running_gmv = 0
    running_quantity_sold = 0
    
    for package_label_record in package_label_records:
    #     print(package_label_record)
        if created_date is None:
            created_date = package_label_record['created_date']
            received_datetime = package_label_record['received_datetime']
            shipped_quantity = package_label_record['shipped_quantity']
            product_category_name = package_label_record['tx_product_category_name']
            product_name = package_label_record['tx_product_name']

        running_gmv += package_label_record['tx_total_price']
        running_quantity_sold += package_label_record['tx_quantity_sold']

        if shipped_quantity is None:
            print('BAD!')
            continue

        sold_ratio = running_quantity_sold / shipped_quantity

        if percent_25_date is None and sold_ratio >= 0.25:
            percent_25_date = package_label_record['sales_date']
            percent_25_days_count = (datetime.strptime(percent_25_date, '%Y-%m-%d') - created_date).days
            percent_25_days_count_norm = (shipped_quantity * 0.25) / percent_25_days_count

        if percent_50_date is None and sold_ratio >= 0.5:
            percent_50_date = package_label_record['sales_date']
            percent_50_days_count = (datetime.strptime(percent_50_date, '%Y-%m-%d') - created_date).days
            percent_50_days_count_norm = (shipped_quantity * 0.5) / percent_50_days_count

        if percent_75_date is None and sold_ratio >= 0.75:
            percent_75_date = package_label_record['sales_date']
            percent_75_days_count = (datetime.strptime(percent_75_date, '%Y-%m-%d') - created_date).days
            percent_75_days_count_norm = (shipped_quantity * 0.75) / percent_75_days_count

        if percent_90_date is None and sold_ratio >= 0.9:
            percent_90_date = package_label_record['sales_date']
            percent_90_days_count = (datetime.strptime(percent_90_date, '%Y-%m-%d') - created_date).days
            percent_90_days_count_norm = (shipped_quantity * 0.9) / percent_90_days_count

        if percent_100_date is None and sold_ratio >= 1.0:
            percent_100_date = package_label_record['sales_date']
            percent_100_days_count = (datetime.strptime(percent_100_date, '%Y-%m-%d') - created_date).days
            percent_100_days_count_norm = (shipped_quantity * 1.0) / percent_100_days_count

    return [
        target_package_label,
        product_category_name,
        product_name,
        created_date.strftime('%Y-%m-%d'),
        received_datetime,
        shipped_quantity,
        running_gmv / running_quantity_sold, # Average sales price per unit
        percent_25_date,
        percent_25_days_count,
        percent_25_days_count_norm,
        percent_50_date,
        percent_50_days_count,
        percent_50_days_count_norm,
        percent_75_date,
        percent_75_days_count,
        percent_75_days_count_norm,
        percent_90_date,
        percent_90_days_count,
        percent_90_days_count_norm,
        percent_100_date,
        percent_100_days_count,
        percent_100_days_count_norm,
    ]

def compute_sell_through_for_package_label(result_dataframe, package_label):
    filter_by_package_label = result_dataframe['package_label'] == package_label
    package_label_result_dataframe = result_dataframe[filter_by_package_label]
    sorted_package_label_result_dataframe = package_label_result_dataframe.sort_values('sales_date', ascending=True)
    package_label_records = sorted_package_label_result_dataframe.to_dict('records')
    return compute_sell_through_for_package_label_records(package_label_records)

# %%
def compute_sell_through_for_incoming_transfer_packages(transfer_packages_file, sales_transactions_file):
    raw_incoming_transfer_packages_dataframe = pandas.read_excel(transfer_packages_file, header=0)
    raw_sales_transactions_dataframe = pandas.read_excel(sales_transactions_file, header=0)
    
    incoming_transfer_packages_dataframe = raw_incoming_transfer_packages_dataframe[[
    #     'date_type',
    #     'transfer_row_id',
    #     'delivery_row_id',
    #     'package_row_id',
        'delivery_type',
        'manifest_number',
        'created_date',
        'received_datetime',
        'shipper_facility_license_number',
        'shipper_facility_name',
        'recipient_facility_license_number',
        'recipient_facility_name',
        'shipment_type_name',
        'shipment_transaction_type',
        'package_id',
        'package_label',
        'type',
        'product_category_name',
        'product_name',
        'shipper_wholesale_price',
        'shipped_quantity',
        'lab_results_status',
        # TODO: payload
    ]]
    sales_transactions_dataframe = raw_sales_transactions_dataframe[[
    #     'date_type',
    #     'id',
        'receipt_id',
        'receipt_number',
        'receipt_type',
        'sales_customer_type',
        'sales_datetime', # IMPORTANT
        'total_packages',
        'total_price',
        'tx_type',
        'tx_package_id',
        'tx_package_label',
        'tx_product_name',
        'tx_product_category_name',
        'tx_unit_of_measure',
        'tx_quantity_sold',
        'tx_total_price',
    ]]
    sales_transactions_dataframe = sales_transactions_dataframe.rename(columns={'tx_package_id': 'package_id'})
    
    fn = lambda row: f'{row.shipper_facility_name} ({row.shipper_facility_license_number})'
    col = incoming_transfer_packages_dataframe.apply(fn, axis=1)
    incoming_transfer_packages_dataframe = incoming_transfer_packages_dataframe.assign(shipper_facility=col.values)

    fn = lambda row: f'{row.created_date.year}-{"0" if row.created_date.month < 10 else ""}{row.created_date.month}'
    col = incoming_transfer_packages_dataframe.apply(fn, axis=1)
    incoming_transfer_packages_dataframe = incoming_transfer_packages_dataframe.assign(created_month=col.values)

    fn = lambda row: f'{row.sales_datetime.year}-{"0" if row.sales_datetime.month < 10 else ""}{row.sales_datetime.month}'
    col = sales_transactions_dataframe.apply(fn, axis=1)
    sales_transactions_dataframe = sales_transactions_dataframe.assign(sales_month=col.values)

    fn = lambda row: f'{row.sales_datetime.year}-{"0" if row.sales_datetime.month < 10 else ""}{row.sales_datetime.month}-{"0" if row.sales_datetime.day < 10 else ""}{row.sales_datetime.day}'
    col = sales_transactions_dataframe.apply(fn, axis=1)
    sales_transactions_dataframe = sales_transactions_dataframe.assign(sales_date=col.values)
    
    result_dataframe = incoming_transfer_packages_dataframe.set_index('package_id').join(sales_transactions_dataframe.set_index('package_id'), on='package_id', how='inner', lsuffix='_l', rsuffix='_r')

    limited_result_dataframe = result_dataframe[[
        'manifest_number',
        'package_label',
        'created_month',
        'created_date',
        'received_datetime',
        'shipper_facility',
        'shipper_facility_license_number',
        'shipper_facility_name',
        'shipped_quantity',
        'sales_month',
        'sales_date',
        'sales_datetime',
        'tx_product_name',
        'tx_product_category_name',
        'tx_unit_of_measure',
        'tx_quantity_sold',
        'tx_total_price',
    ]]

    unique_package_labels = limited_result_dataframe.package_label.unique()
    sell_throughs = [compute_sell_through_for_package_label(limited_result_dataframe, package_label) for package_label in unique_package_labels]
    sell_throughs_dataframe = pandas.DataFrame(
        sell_throughs,
        columns=[
            'package_label',
            'product_category_name',
            'product_name',
            'created_date',
            'received_datetime',
            'shipped_quantity',
            'average_sales_price',
            'percent_25_date',
            'percent_25_days_count',
            'percent_25_days_count_norm',
            'percent_50_date',
            'percent_50_days_count',
            'percent_50_days_count_norm',
            'percent_75_date',
            'percent_75_days_count',
            'percent_75_days_count_norm',
            'percent_90_date',
            'percent_90_days_count',
            'percent_90_days_count_norm',
            'percent_100_date',
            'percent_100_days_count',
            'percent_100_days_count_norm',
        ])
    
    return sell_throughs_dataframe

# %%
sell_throughs_dataframe = compute_sell_through_for_incoming_transfer_packages(
    transfer_packages_file='data/metrc_transfer_packages_manifest_number_0002359694.xlsx',
    sales_transactions_file='data/royal/royal_apothecary_sales_transactions_20210101_20210905.xlsx',
)
# Out:
# /Users/warren/venvs/bespoke/lib/python3.7/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
sell_throughs_dataframe
# Out:
#                package_label             product_category_name  \
# 0   1A406030000390D000020513                   Pre-Roll Flower
# 1   1A406030000390D000020513                   Pre-Roll Flower
# 2   1A406030000390D000020513                   Pre-Roll Flower
# 3   1A406030000390D000020513                   Pre-Roll Flower
# 4   1A406030000390D000020513           Extract (weight - each)
# 5   1A406030000390D000020513  Flower (packaged quarter - each)
# 6   1A406030000390D000020513   Flower (packaged eighth - each)
# 7   1A406030000390D000020513   Flower (packaged eighth - each)
# 8   1A406030000390D000020513                   Pre-Roll Flower
# 9   1A406030000390D000020513   Flower (packaged eighth - each)
# 10  1A406030000390D000020513                   Pre-Roll Flower
# 11  1A406030000390D000020513   Flower (packaged eighth - each)
# 12  1A406030000390D000020513                   Pre-Roll Flower
# 13  1A406030000390D000020513   Flower (packaged eighth - each)
#
#                                          product_name created_date  \
# 0        Sticks Preroll - Dragon OG - 1g / Case of 44   2021-08-25
# 1   Sticks Preroll - Purple Gorilla - 1g / Case of 44   2021-08-25
# 2     Korova Preroll - Purple Punch - 1g / Case of 50   2021-08-25
# 3   Korova Preroll - Wedding Crasher - 1g / Case o...   2021-08-25
# 4   Korova Extract - Diamond Shatter: Imperium X -...   2021-08-25
# 5   Korova Flower - Jet Fuel Gelato - 7g / Case of 32   2021-08-25
# 6   Korova Flower - Alien Apple Fritter - 3.5g / C...   2021-08-25
# 7   Korova Flower - Golden Strawberries - 3.5g / C...   2021-08-25
# 8       Sticks Preroll - Banana Mac - 1g / Case of 44   2021-08-25
# 9        Sticks Flower - Alpha OG - 3.5g / Case of 40   2021-08-25
# 10         Sticks Preroll - Zookies - 1g / Case of 44   2021-08-25
# 11  Unrivaled Flower - Kush Mints - 3.5g / Case of 32   2021-08-25
# 12  Trade Sample Korova Preroll - Tahoe Alien - 1g...   2021-08-25
# 13       Unrivaled Flower - Fatso - 3.5g / Case of 32   2021-08-25
#
#      received_datetime  shipped_quantity  average_sales_price percent_25_date  \
# 0  2021-08-25 21:44:54                44             6.933333      2021-08-31
# 1  2021-08-25 21:44:54                44             7.600000            None
# 2  2021-08-25 21:44:54                50            11.900000            None
# 3  2021-08-25 21:44:54                50            11.200000            None
# 4  2021-08-25 21:44:54                30            26.256667            None
# 5  2021-08-25 21:44:54                32            71.509000      2021-09-04
# 6  2021-08-25 21:44:54                32            43.557586      2021-08-30
# 7  2021-08-25 21:44:54                32            41.116667            None
# 8  2021-08-25 21:44:54                44             6.800000            None
# 9  2021-08-25 21:44:54                40            21.452105      2021-08-27
# 10 2021-08-25 21:44:54                44             7.333333            None
# 11 2021-08-25 21:44:54                64            52.941905      2021-09-01
# 12 2021-08-25 21:44:54                50             8.400000            None
# 13 2021-08-25 21:44:54                64            58.910000            None
#
#     percent_25_days_count  percent_25_days_count_norm  ...  \
# 0                     6.0                    1.833333  ...
# 1                     NaN                         NaN  ...
# 2                     NaN                         NaN  ...
# 3                     NaN                         NaN  ...
# 4                     NaN                         NaN  ...
# 5                    10.0                    0.800000  ...
# 6                     5.0                    1.600000  ...
# 7                     NaN                         NaN  ...
# 8                     NaN                         NaN  ...
# 9                     2.0                    5.000000  ...
# 10                    NaN                         NaN  ...
# 11                    7.0                    2.285714  ...
# 12                    NaN                         NaN  ...
# 13                    NaN                         NaN  ...
#
#    percent_50_days_count_norm  percent_75_date  percent_75_days_count  \
# 0                         NaN             None                    NaN
# 1                         NaN             None                    NaN
# 2                         NaN             None                    NaN
# 3                         NaN             None                    NaN
# 4                         NaN             None                    NaN
# 5                         NaN             None                    NaN
# 6                    2.666667       2021-09-02                    8.0
# 7                         NaN             None                    NaN
# 8                         NaN             None                    NaN
# 9                    4.000000       2021-09-03                    9.0
# 10                        NaN             None                    NaN
# 11                        NaN             None                    NaN
# 12                        NaN             None                    NaN
# 13                        NaN             None                    NaN
#
#    percent_75_days_count_norm  percent_90_date  percent_90_days_count  \
# 0                         NaN             None                    NaN
# 1                         NaN             None                    NaN
# 2                         NaN             None                    NaN
# 3                         NaN             None                    NaN
# 4                         NaN             None                    NaN
# 5                         NaN             None                    NaN
# 6                    3.000000       2021-09-05                   11.0
# 7                         NaN             None                    NaN
# 8                         NaN             None                    NaN
# 9                    3.333333       2021-09-05                   11.0
# 10                        NaN             None                    NaN
# 11                        NaN             None                    NaN
# 12                        NaN             None                    NaN
# 13                        NaN             None                    NaN
#
#    percent_90_days_count_norm  percent_100_date  percent_100_days_count  \
# 0                         NaN              None                    None
# 1                         NaN              None                    None
# 2                         NaN              None                    None
# 3                         NaN              None                    None
# 4                         NaN              None                    None
# 5                         NaN              None                    None
# 6                    2.618182              None                    None
# 7                         NaN              None                    None
# 8                         NaN              None                    None
# 9                    3.272727              None                    None
# 10                        NaN              None                    None
# 11                        NaN              None                    None
# 12                        NaN              None                    None
# 13                        NaN              None                    None
#
#    percent_100_days_count_norm
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# 5                         None
# 6                         None
# 7                         None
# 8                         None
# 9                         None
# 10                        None
# 11                        None
# 12                        None
# 13                        None
#
# [14 rows x 22 columns]

# %%
import time

manifest_number = '0002359694'
xlsx_file_name = f'~/Downloads/sell_throughs_data_manifest_number_{manifest_number}_{round(time.time())}.xlsx'
sell_throughs_dataframe.to_excel(xlsx_file_name, index=False)

# %%
# TODOs
# 1. Merge together packages of the same product with the same created date
# 2.
