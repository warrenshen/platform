# %%
import pandas as pd
import numpy as np
import pyodbc

# %%
# pd.set_option('display.max_colwidth', -1)
pd.options.display.min_rows = 100

# %%
ar_reports_df = pd.read_excel('ar_reports_cleaned.xlsx')

# %%
ar_reports_df['license_number'] = ar_reports_df['license_number'].replace('NUG Sacramento | Community Health Solutions', 'C10-0000508-LIC')

# %%
ar_reports_df.columns
# Out:
# Index(['license_number', 'license_provided', 'ar_company', 'ar_company_state',
#        'count_payor', 'sum_days_over', 'orig_amt', 'bal_out', 'current',
#        '30_days', '60_days', '90_days', 'over_90_days', 'delinquent', 'date',
#        'client', 'client_state', 'summary', 'a', 'b', 'why_no_lic', 'notes'],
#       dtype='object')

# %%
# Engine for California Data
ca_conn = pyodbc.connect(server = 'bespoke-database-1.cmevrozrcs7c.us-west-2.rds.amazonaws.com', 
                      driver = '{ODBC Driver 17 for SQL Server}',
                      database = 'ca_cannabis',
                      UID = 'admin',
                      PWD = 'N19lrqxnurTUJLJT6GFe')

# %%
# Engine for Colorado Data
co_conn = pyodbc.connect(server = 'bespoke-database-1.cmevrozrcs7c.us-west-2.rds.amazonaws.com', 
                      driver = '{ODBC Driver 17 for SQL Server}',
                      database = 'co_cannabis',
                      UID = 'admin',
                      PWD = 'N19lrqxnurTUJLJT6GFe')

# %%
# Engine for Illinois Data
il_conn = pyodbc.connect(server = 'bespoke-database-1.cmevrozrcs7c.us-west-2.rds.amazonaws.com', 
                      driver = '{ODBC Driver 17 for SQL Server}',
                      database = 'il_cannabis',
                      UID = 'admin',
                      PWD = 'N19lrqxnurTUJLJT6GFe')

# %%
# Engine for Nevada Data
nv_conn = pyodbc.connect(server = 'bespoke-database-1.cmevrozrcs7c.us-west-2.rds.amazonaws.com', 
                      driver = '{ODBC Driver 17 for SQL Server}',
                      database = 'nv_cannabis',
                      UID = 'admin',
                      PWD = 'N19lrqxnurTUJLJT6GFe')

# %%
# Engine for Oregon Data
or_conn = pyodbc.connect(server = 'bespoke-database-1.cmevrozrcs7c.us-west-2.rds.amazonaws.com', 
                      driver = '{ODBC Driver 17 for SQL Server}',
                      database = 'or_cannabis',
                      UID = 'admin',
                      PWD = 'N19lrqxnurTUJLJT6GFe')

# %%
# Engine for Washington Data
wa_conn = pyodbc.connect(server = 'bespoke-database-1.cmevrozrcs7c.us-west-2.rds.amazonaws.com', 
                      driver = '{ODBC Driver 17 for SQL Server}',
                      database = 'wa_cannabis',
                      UID = 'admin',
                      PWD = 'N19lrqxnurTUJLJT6GFe')

# %%
ca_roll = pd.read_sql("SELECT * FROM ca_roll", ca_conn)
co_roll = pd.read_sql("SELECT * FROM co_roll", co_conn)
il_roll = pd.read_sql("SELECT * FROM il_roll", il_conn) 
nv_roll = pd.read_sql("SELECT * FROM nv_roll", nv_conn) 
or_roll = pd.read_sql("SELECT * FROM or_roll", or_conn) 
wa_roll = pd.read_sql("SELECT * FROM wa_roll", wa_conn)

# %%
ar_reports_df['license_number'] = ar_reports_df['license_number'].replace('c9-', 'C9-')
ar_reports_df['license_number'] = ar_reports_df['license_number'].replace('c10-', 'C10-')
ar_reports_df['license_number'] = ar_reports_df['license_number'].replace('c11-', 'C11-')
ar_reports_df['license_number'] = ar_reports_df['license_number'].replace('c12-', 'C12-')

# %%
# for n in range(len(ar_reports_df)):
#     if ar_reports_df['license_number'][n] == '0':
#         ar_reports_df['ar_company_state'][n] = '0'
        
#     elif ar_reports_df['license_number'][n] in list(ca_roll['license_number']):
#         ar_reports_df['ar_company_state'][n] = 'CA'
#     elif ar_reports_df['license_number'][n][:3] == 'C9-':
#         ar_reports_df['ar_company_state'][n] = 'CA'
#     elif ar_reports_df['license_number'][n][:4] == 'C10-':
#         ar_reports_df['ar_company_state'][n] = 'CA'
#     elif ar_reports_df['license_number'][n][:4] == 'C11-':
#         ar_reports_df['ar_company_state'][n] = 'CA'
        
        
#     elif ar_reports_df['license_number'][n][:4] == 'MMDF':
#         ar_reports_df['ar_company_state'][n] = 'CT'
    
        
        
#     elif ar_reports_df['license_number'][n] in list(co_roll['license_number']):
#         ar_reports_df['ar_company_state'][n] = 'CO'
#     elif ar_reports_df['license_number'][n][:4] == '402-':
#         ar_reports_df['ar_company_state'][n] = 'CO'
        
        
        
#     elif ar_reports_df['license_number'][n] in list(il_roll['license_number']):
#         ar_reports_df['ar_company_state'][n] = 'IL'
        
        
#     elif ar_reports_df['license_number'][n] in list(nv_roll['license_number']):
#         ar_reports_df['ar_company_state'][n] = 'NV'
#     elif ar_reports_df['license_number'][n][:4] == 'M66-':
#         ar_reports_df['ar_company_state'][n] = 'NV'
    
        
        
#     elif ar_reports_df['license_number'][n] in list(or_roll['license_number']):
#         ar_reports_df['ar_company_state'][n] = 'OR'
#     elif ar_reports_df['license_number'][n][:4] == '050 ':
#         ar_reports_df['ar_company_state'][n] = 'OR'
#     elif ar_reports_df['license_number'][n] in list(wa_roll['license_number']):
#         ar_reports_df['ar_company_state'][n] = 'WA'
#     elif ar_reports_df['license_number'][n][:3] == 'PC-':
        
#         ar_reports_df['ar_company_state'][n] = 'MI'
#     elif ar_reports_df['license_number'][n][:3] == 'MC2':
#         ar_reports_df['ar_company_state'][n] = 'MA'
#     elif ar_reports_df['license_number'][n][:3] == 'MR2':
#         ar_reports_df['ar_company_state'][n] = 'MA'
#     elif ar_reports_df['license_number'][n][:3] == 'RMD':
#         ar_reports_df['ar_company_state'][n] = 'MA'
#     elif ar_reports_df['license_number'][n][:4] == 'DAAA':
#         ar_reports_df['ar_company_state'][n] = 'OK'
# Out:
# C:\Users\nolan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\nolan\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\nolan\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
ar_reports_df['ar_company_state'].value_counts()
# Out:
# CA     24805
# 0.0     2201
# OR       338
# CO       252
# MA        14
# MI        14
# OK        13
# CT         2
# NV         1
# Name: ar_company_state, dtype: int64

# %%
ar_reports_df.iloc[2213]['license_number'][:3]
# Out:
# '020'

# %%
ar_reports_df[ar_reports_df['ar_company_state'].isnull()]
# Out:
#               license_number  license_provided  \
# 2201   000000113DCUX00454549                 0
# 2202    00000018DCST00941489                 0
# 2203    00000018ESKD27426528                 0
# 2204    00000019DCGM00234427                 0
# 2205    00000039DCVR00320237                 0
# 2206    00000042DCSI00109560                 0
# 2207    00000053DCXB00858835                 0
# 2208    00000054DCOV00321891                 0
# 2209    00000063DCTB00283389                 0
# 2210    00000077DCPS00215501                 0
# 2211    00000091DCWY00555666                 0
# 2212    00000126DCSO00060479                 0
# 2551             1.07565e+19                 0
# 2552             1000360C340                 0
# 2553             1000360C340                 0
# 2554             1000360C340                 0
# 2555            10004923B1AA                 0
# 2556            10004923B1AA                 0
# 2557            10004923B1AA                 0
# ...

# %%
ca_roll
# Out:
#         license_number roll_up_id                  company_roll_up
# 0      C11-0000615-LIC   CA-00039                              300
# 1        CDPH-10003352   CA-00039                              300
# 2        CCL19-0003643   CA-00001                              00g
# 3        CDPH-10003551   CA-00002      1000 palms associates group
# 4      C11-0000630-LIC   CA-00002      1000 palms associates group
# 5        CCL19-0000084   CA-00002      1000 palms associates group
# 6      C11-0000596-LIC   CA-00003           10th street facilities
# 7        CCL19-0002577   CA-00003           10th street facilities
# 8        CDPH-10003795   CA-00003           10th street facilities
# 9      C11-0000508-LIC   CA-00004                 12/12 management
# 10       CCL18-0002051   CA-00005                    1212 genetics
# 11     C11-0000234-LIC   CA-00005                    1212 genetics
# 12       CDPH-10003647   CA-00006                      1215 briggs
# ...

# %%
ca_main = pd.read_sql("SELECT * FROM ca_main", ca_conn)
co_main = pd.read_sql("SELECT * FROM co_main", co_conn)
il_main = pd.read_sql("SELECT * FROM il_main", il_conn) 
nv_main = pd.read_sql("SELECT * FROM nv_main", nv_conn) 
or_main = pd.read_sql("SELECT * FROM or_main", or_conn) 
wa_main = pd.read_sql("SELECT * FROM wa_main", wa_conn)

# %%
for n in range(len(ar_reports_df)):
    
    if ar_reports_df['client_state'][n] == '':
    
        if ar_reports_df['client'][n] in list(ca_main['name_legal']):
            ar_reports_df['client_state'][n] = 'CA'
        elif ar_reports_df['client'][n] in list(ca_main['name_dba']):
            ar_reports_df['client_state'][n] = 'CA'

        elif ar_reports_df['client'][n] in list(co_main['name_legal']):
            ar_reports_df['client_state'][n] = 'CO'
        elif ar_reports_df['client'][n] in list(co_main['name_dba']):
            ar_reports_df['client_state'][n] = 'CO'

        elif ar_reports_df['client'][n] in list(il_main['name_legal']):
            ar_reports_df['client_state'][n] = 'IL'
        elif ar_reports_df['client'][n] in list(il_main['name_dba']):
            ar_reports_df['client_state'][n] = 'IL'

        elif ar_reports_df['client'][n] in list(nv_main['name_legal']):
            ar_reports_df['client_state'][n] = 'NV'
    #     elif ar_reports_df['client'][n] in list(nv_main['name_dba']):
    #         ar_reports_df['client_state'][n] = 'NV'

        elif ar_reports_df['client'][n] in list(or_main['name_legal']):
            ar_reports_df['client_state'][n] = 'OR'
        elif ar_reports_df['client'][n] in list(or_main['name_dba']):
            ar_reports_df['client_state'][n] = 'OR'

        elif ar_reports_df['client'][n] in list(wa_main['name_legal']):
            ar_reports_df['client_state'][n] = 'WA'
    #     elif ar_reports_df['client'][n] in list(wa_main['name_dba']):
    #         ar_reports_df['client_state'][n] = 'WA'



        else:
            ar_reports_df['client_state'][n] = '0'

# %%
ar_reports_df['client_state'].value_counts()
# Out:
# 0     24940
# CA     2707
# OR       45
# IL        8
# Name: client_state, dtype: int64

# %%
len(ar_reports_df)
# Out:
# 27700

# %%
print(stop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4f76a9dad686> in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
ar_reports_df.to_excel('ar_reports_cleaned.xlsx', index=False)
